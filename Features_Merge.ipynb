# %%
import pandas as pd

# %%
LDA = pd.read_csv('LDA_features.csv')
D2V = pd.read_csv('doc2vec_vectors_final.csv')

# %%
combined = pd.concat([LDA, D2V], axis = 1)

# %%
combined
# Out:
#        Unnamed: 0   topic_0   topic_1   topic_2   topic_3   topic_4   topic_5  \
# 0               0  0.029291  0.122669  0.078690  0.509404  0.257012  0.000000
# 1               1  0.072681  0.114266  0.434530  0.297216  0.072028  0.000000
# 2               2  0.532546  0.181123  0.050537  0.051361  0.069668  0.113055
# 3               3  0.269257  0.163069  0.563442  0.000000  0.000000  0.000000
# 4               4  0.045626  0.066652  0.133848  0.193264  0.556775  0.000000
# ...           ...       ...       ...       ...       ...       ...       ...
# 18841       18841  0.096824  0.028508  0.015213  0.014549  0.153450  0.612585
# 18842       18842  0.482376  0.474755  0.000000  0.000000  0.000000  0.000000
# 18843       18843  0.040313  0.081552  0.085471  0.071569  0.504859  0.212136
# 18844       18844  0.064360  0.862725  0.062406  0.000000  0.000000  0.000000
# 18845       18845  0.016048  0.026194  0.126416  0.104298  0.059771  0.399715
#
# ...

# %%
combined.to_csv('merged.csv', index = False)
