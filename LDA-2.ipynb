# %%
from sklearn.datasets import fetch_20newsgroups
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim import corpora

# %%
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
df = pd.DataFrame({'text': newsgroups.data, 'label': newsgroups.target})
df['label'] = df['label'].map(lambda x: newsgroups.target_names[x])
df
# Out:
#                                                     text  \
# 0      \n\nI am sure some bashers of Pens fans are pr...
# 1      My brother is in the market for a high-perform...
# 2      \n\n\n\n\tFinally you said what you dream abou...
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...
# 4      1)    I have an old Jasmine drive which I cann...
# ...                                                  ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...
# 18842  \nNot in isolated ground recepticles (usually ...
# 18843  I just installed a DX2-66 CPU in a clone mothe...
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....
#
#                           label
# 0              rec.sport.hockey
# 1      comp.sys.ibm.pc.hardware
# 2         talk.politics.mideast
# 3      comp.sys.ibm.pc.hardware
# 4         comp.sys.mac.hardware
# ...                         ...
# 18841                   sci.med
# 18842           sci.electronics
# 18843  comp.sys.ibm.pc.hardware
# 18844             comp.graphics
# 18845                 rec.autos
#
# [18846 rows x 2 columns]

# %%
def preprocessing(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'[^A-Za-z ]+', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words and len(word)>=3]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    processed_text = ' '.join(tokens)
    return processed_text

# %%
df['processed_text'] = df['text'].apply(lambda x: preprocessing(x))

# %%
df = df.drop('label',axis=1)
df
# Out:
#                                                     text  \
# 0      \n\nI am sure some bashers of Pens fans are pr...
# 1      My brother is in the market for a high-perform...
# 2      \n\n\n\n\tFinally you said what you dream abou...
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...
# 4      1)    I have an old Jasmine drive which I cann...
# ...                                                  ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...
# 18842  \nNot in isolated ground recepticles (usually ...
# 18843  I just installed a DX2-66 CPU in a clone mothe...
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....
#
#                                           processed_text
# 0      sure bashers pen fan pretty confused lackof ki...
# 1      brother market highperformance video card supp...
# 2      finally said dream mediterranean newthe area g...
# 3      thinkits scsi card dma transfer disksthe scsi ...
# 4      old jasmine drive use new system understanding...
# ...                                                  ...
# 18841  nyedacnsvaxuwecedu david nyedn neurologydn con...
# 18842  isolated ground recepticles usually unusual co...
# 18843  installed cpu clone motherboard tried mounting...
# 18844  wouldnt require hypersphere space point specif...
# 18845  tip gary crum crumfcomccutahedu got phonewith ...
#
# [18846 rows x 2 columns]

# %%
from gensim.models import Phrases

df['tokens'] = df['processed_text'].str.split(' ')
tokens = df['tokens'].tolist()
bigram = Phrases(tokens)
trigram = Phrases(bigram[tokens], min_count=1)
tokens = list(trigram[bigram[tokens]])
tokens
# Out:
# [['sure',
#   'bashers',
#   'pen_fan',
#   'pretty',
#   'confused',
#   'lackof',
#   'kind',
#   'post',
#   'recent',
#   'pen',
#   'massacre',
#   'devil',
#   'actuallyi',
#   'bit_puzzled',
#   'bit',
#   'relieved',
#   'however',
#   'going',
#   'put_endto',
#   'nonpittsburghers',
#   'relief',
#   'bit',
#   'praise',
#   'pen',
#   'man',
#   'theyare',
#   'killing',
#   'devil',
#   'worse',
#   'thought',
#   'jagr',
#   'showed',
#   'whyhe',
#   'much_better',
#   'regular_season_stats',
#   'also',
#   'lotfo',
#   'fun_watch',
#   'playoff',
#   'bowman',
#   'let',
#   'jagr',
#   'lot',
#   'offun',
#   'next_couple',
#   'game',
#   'since',
#   'pen',
#   'going_beat',
#   'pulp',
#   'jersey',
#   'anyway',
#   'disappointed',
#   'see',
#   'islander',
#   'lose',
#   'finalregular',
#   'season',
#   'game_pen',
#   'rule'],
#  ['brother',
#   'market',
#   'highperformance_video_card',
#   'supportsvesa',
#   'local_bus',
#   'ram',
#   'anyone',
#   'suggestionsideas',
#   'diamond_stealth_pro',
#   'local_bus',
#   'orchid',
#   'farenheit',
#   'ati_graphic_ultra_pro',
#   'highperformance',
#   'vlb',
#   'cardplease',
#   'post_email',
#   'thank',
#   'matt'],
#  ['finally_said',
#   'dream',
#   'mediterranean',
#   'newthe',
#   'area',
#   'greater',
#   'year',
#   'like',
#   'holocaust',
#   'numbersist',
#   'july',
#   'usa',
#   'sweden',
#   'april',
#   'still',
#   'coldor',
#   'changed',
#   'calendar',
#   'nothing',
#   'mentioned',
#   'true',
#   'let_say',
#   'trueshall',
#   'azeri_woman_child',
#   'going',
#   'pay_price',
#   'raped_killed',
#   'tortured',
#   'armenianshave',
#   'hearded',
#   'something_called',
#   'geneva',
#   'conventionyou',
#   'facistohhh',
#   'forgot_armenian',
#   'fight',
#   'nobody',
#   'forgotyou',
#   'killing',
#   'rapings',
#   'torture',
#   'kurd_turk',
#   'onceupon',
#   'time',
#   'ohhhh',
#   'swedish',
#   'redcross',
#   'worker',
#   'lie_ever',
#   'sayregional',
#   'killer',
#   'dont_like',
#   'person',
#   'shoot',
#   'thats',
#   'policyliiiconfusedii',
#   'search_turkish_plane',
#   'dont_know_talking',
#   'abouti',
#   'turkey',
#   'government_announced',
#   'giving',
#   'weapon',
#   'azerbadjan_since',
#   'armenia_started',
#   'attack',
#   'azerbadjan',
#   'self_karabag',
#   'province_search',
#   'plane',
#   'weapon',
#   'since',
#   'content_announced',
#   'weapon',
#   'one',
#   'thats',
#   'confused',
#   'thats_right',
#   'doto',
#   'give',
#   'weapon',
#   'azeri',
#   'since',
#   'armenian',
#   'started',
#   'fight',
#   'azerbadjan',
#   'shoot',
#   'armenian',
#   'bread_butter',
#   'arm',
#   'personel',
#   'russian_army'],
#  ['thinkits',
#   'scsi_card_dma',
#   'transfer',
#   'disksthe',
#   'scsi_card_dma',
#   'transfer',
#   'containing',
#   'data',
#   'scsi',
#   'devicesit',
#   'attached',
#   'want',
#   'toan',
#   'important_feature',
#   'scsi_ability',
#   'detach_device',
#   'free',
#   'thescsi',
#   'bus_device',
#   'typically',
#   'used',
#   'multitasking',
#   'tostart',
#   'transfer',
#   'several',
#   'device',
#   'device',
#   'seeking',
#   'data',
#   'thebus',
#   'free',
#   'command',
#   'data_transfer',
#   'device',
#   'areready',
#   'transfer_data',
#   'aquire',
#   'bus',
#   'send',
#   'dataon',
#   'ide_bus',
#   'start',
#   'transfer',
#   'bus',
#   'busy',
#   'disk',
#   'seekedthe',
#   'data',
#   'transfered',
#   'typically',
#   'second',
#   'lock',
#   'otherprocesses',
#   'wanting',
#   'bus',
#   'irrespective',
#   'transfer',
#   'time'],
#  ['old',
#   'jasmine',
#   'drive',
#   'use',
#   'new',
#   'system',
#   'understanding',
#   'upsate',
#   'driver',
#   'modernone',
#   'order_gain',
#   'compatability',
#   'system',
#   'anyone_knowof',
#   'inexpensive',
#   'program',
#   'seen',
#   'formatters',
#   'buit',
#   'idea',
#   'work',
#   'another',
#   'ancient',
#   'device',
#   'one',
#   'tape_drive',
#   'whichthe',
#   'back',
#   'utility',
#   'freeze',
#   'system',
#   'try',
#   'use',
#   'drive',
#   'ajasmine',
#   'direct',
#   'tape',
#   'bought',
#   'used',
#   'tape',
#   'techmarmechanism',
#   'essentially',
#   'question',
#   'anyone_knowof',
#   'inexpensive',
#   'beckup',
#   'utility',
#   'use',
#   'system'],
#  ['back_high_school',
#   'worked',
#   'lab',
#   'assistant',
#   'bunch',
#   'experimentalpsychologists',
#   'bell_lab',
#   'visual_perception',
#   'andmemory',
#   'experiment',
#   'used',
#   'vectortype',
#   'display',
#   'millisecondrefresh',
#   'rate',
#   'commonso',
#   'case',
#   'sec',
#   'quite',
#   'practical',
#   'experimenter',
#   'wereprobably',
#   'sure',
#   'millisecond',
#   'eithersteve'],
#  ['dallastry',
#   'tech_support',
#   'may',
#   'ontheir',
#   'line',
#   'one',
#   'get',
#   'started'],
#  ['stuff_deletedok',
#   'here',
#   'solution_problem',
#   'move',
#   'canada',
#   'yesterday',
#   'ableto',
#   'watch',
#   'four',
#   'gamesthe',
#   'njpitt',
#   'abc',
#   'lacal',
#   'cbc',
#   'buffbos',
#   'tsn',
#   'fox',
#   'monque',
#   'cbc',
#   'think',
#   'ifeach',
#   'series_go',
#   'max',
#   'could',
#   'watching',
#   'hockey_playoff',
#   'oddconsecutive',
#   'night',
#   'havent_counted',
#   'thats',
#   'pure',
#   'guessi',
#   'two',
#   'tv',
#   'house',
#   'set',
#   'sidebyside',
#   'watch',
#   'monqueand',
#   'keep_eye',
#   'bosbuff',
#   'time',
#   'twoafternoon',
#   'gamesbtw',
#   'abc',
#   'commentaters',
#   'great',
#   'quite_impressed',
#   'seemedto',
#   'know',
#   'audience',
#   'wasnt',
#   'likely',
#   'wellschooled',
#   'hockey',
#   'loreand',
#   'excellent_job',
#   'quite',
#   'impartial',
#   'also',
#   'imo'],
#  ['yeah',
#   'second',
#   'one',
#   'believe',
#   'price',
#   'ive',
#   'tryingto_get',
#   'good',
#   'look',
#   'bruinsabre',
#   'telecast',
#   'wow',
#   'everlook',
#   'good',
#   'whoever',
#   'paint_job',
#   'knew',
#   'givenfuhrs',
#   'play',
#   'since',
#   'got',
#   'bet',
#   'bruin',
#   'wishing',
#   'didnt'],
#  ['christian',
#   'mean',
#   'someone',
#   'belief',
#   'divinity',
#   'jesus',
#   'safeto',
#   'say',
#   'jesus',
#   'christianon',
#   'first_day_christmas',
#   'truelove_served_leftover_turkeyon',
#   'second_day_christmas',
#   'truelove_served_turkey_casserole',
#   'made_leftover_turkeydays_deleted',
#   'flaming_turkey_wing_pizza',
#   'hut_commercial_mtluagic_bait'],
#  ['blood',
#   'lambthis',
#   'hard',
#   'task',
#   'culture',
#   'used',
#   'animalsfor',
#   'blood_sacrifice',
#   'something',
#   'related',
#   'currentpostmodernism',
#   'state',
#   'hmm',
#   'used',
#   'computerscheerskent'],
#  ['say', 'history_untrustworthy', 'behavoirsic'],
#  ['thou_wilt',
#   'shall_whole',
#   'law',
#   'honestlythe',
#   'word',
#   'sin',
#   'restriction',
#   'would',
#   'kid',
#   'youdoes',
#   'one',
#   'man',
#   'word',
#   'encompass',
#   'majestic',
#   'vision',
#   'thousandsof',
#   'individual',
#   'quoting_man',
#   'quoting',
#   'theorder',
#   'taken_context',
#   'word_interpreted',
#   'muchdifferently',
#   'one',
#   'applied',
#   'within',
#   'confines',
#   'oftheir',
#   'original',
#   'expressioni',
#   'think',
#   'case',
#   'regarding',
#   'hymenaeus_beta',
#   'frater_superior',
#   'order',
#   'belong',
#   'included',
#   'bitfrom',
#   'merlinus',
#   'service',
#   'showed',
#   'extremesto',
#   'order',
#   'member',
#   'known',
#   'fervori',
#   'little',
#   'knowledge',
#   'regarding',
#   'reuss',
#   'background',
#   'surelyhe',
#   'unusual',
#   'man',
#   'important',
#   'force',
#   'order',
#   'many',
#   'yearsyet',
#   'people',
#   'change',
#   'order',
#   'change',
#   'look',
#   'backso',
#   'carefully',
#   'dirty',
#   'laundry',
#   'oto',
#   'remember',
#   'isonly',
#   'surface',
#   'skim',
#   'many',
#   'perspective',
#   'encompassedwhich',
#   'extend_beyond',
#   'one',
#   'individual',
#   'hope',
#   'show',
#   'therewas',
#   'much',
#   'room',
#   'difference_opinion',
#   'within',
#   'orderitself',
#   'perhaps',
#   'testing',
#   'limit',
#   'myselflet',
#   'examine_issue',
#   'bit',
#   'closelyin',
#   'karl',
#   'kellner',
#   'wealthy',
#   'austrian',
#   'industrialistand',
#   'paper',
#   'chemist',
#   'well',
#   'highgrade',
#   'mason',
#   'founded',
#   'ordotempli',
#   'orientis',
#   'kellner',
#   'traveled',
#   'widely',
#   'east',
#   'hemet',
#   'three',
#   'adept',
#   'instructed',
#   'specific',
#   'magical',
#   'practice',
#   'kellners',
#   'effort_develop',
#   'order',
#   'later',
#   'assisted',
#   'franzhartmann',
#   'heinrich',
#   'klein',
#   'theodore_reuss',
#   'worked',
#   'togetherprior',
#   'joining',
#   'oto',
#   'order',
#   'first',
#   'proclaimed',
#   'reusss',
#   'masonic',
#   'publication',
#   'oriflamme',
#   'kellners',
#   'deathreuss',
#   'succeeded',
#   'outer_head',
#   'oho',
#   'jubilee',
#   'edition_ofthe',
#   'oriflamme',
#   'published',
#   'announced',
#   'order',
#   'taughtsecret',
#   'sexual',
#   'magic',
#   'theodore_reuss',
#   'interesting',
#   'character',
#   'born',
#   'june',
#   'inaugsburg',
#   'entered',
#   'masonry',
#   'singer',
#   'journalist',
#   'andpossibly',
#   'spy',
#   'prussian',
#   'political',
#   'police',
#   'infiltrating',
#   'socialistleague',
#   'founded',
#   'karl_marx',
#   'daughter',
#   'husband',
#   'reuss',
#   'waslater',
#   'associated',
#   'william',
#   'wynn',
#   'westcott',
#   'leader',
#   'goldendawn',
#   'later',
#   'introduced',
#   'john',
#   'yarker',
#   'yarker',
#   'chartered',
#   'reuss',
#   'tofound',
#   'rite',
#   'memphis',
#   'mizraim',
#   'germany',
#   'severalattempts',
#   'concretize',
#   'various',
#   'masonic',
#   'rite',
#   'reuss',
#   'settled',
#   'thedevelopment',
#   'otothe',
#   'order',
#   'experienced',
#   'reasonably',
#   'steady',
#   'growth',
#   'reuss',
#   'leadershipfor',
#   'example',
#   'chartered',
#   'papus',
#   'france',
#   'rudolph',
#   'steiner',
#   'berlinand',
#   'spencer_lewis',
#   'usa',
#   'historic',
#   'meeting',
#   'betweenreuss',
#   'crowley',
#   'occurred',
#   'crowley',
#   'wrote',
#   'reuss',
#   'came',
#   'andaccused',
#   'revealing',
#   'order',
#   'secret',
#   'crowley',
#   'looked',
#   'afreshthe',
#   'initiated',
#   'interpretation',
#   'sexual',
#   'magick',
#   'unfolded',
#   'forthe',
#   'first_time',
#   'reuss',
#   'appointed',
#   'crowley',
#   'supreme',
#   'holy',
#   'king',
#   'allthe',
#   'english_speaking',
#   'world',
#   'authorization',
#   'invokedwhen',
#   'publishing',
#   'material',
#   'equinoxreuss',
#   'resigned',
#   'outer_head',
#   'order',
#   'suffering',
#   'astroke',
#   'named',
#   'crowley',
#   'successor',
#   'well_whenthe',
#   'book',
#   'law',
#   'translated',
#   'german',
#   'breakin',
#   'continuity',
#   'order',
#   'manyk',
#   'member',
#   'split',
#   'new',
#   'ohoover',
#   'book',
#   'crowley',
#   'actively',
#   'promulgating',
#   'orderhe',
#   'earlier',
#   'revise',
#   'dthe',
#   'order_ritual',
#   'reusss',
#   'request',
#   'deeplyinfusing',
#   'doctrine',
#   'new',
#   'aeon',
#   'revelationan',
#   'introduction',
#   'history',
#   'oto',
#   'veritatem',
#   'ixwithin',
#   'equinox_iii',
#   'edited',
#   'hymenaeus_beta',
#   'frater_superior',
#   'rex_summus',
#   'sanctissimus',
#   'caliph',
#   'united_state_america',
#   'published',
#   'samuel',
#   'weiser',
#   'many',
#   'possible',
#   'reason',
#   'frater_superior',
#   'included',
#   'thismaterial',
#   'equinox_iii',
#   'real',
#   'point',
#   'notwhy',
#   'wish',
#   'publish',
#   'thing',
#   'history',
#   'ownorganization',
#   'represent',
#   'dogmatic',
#   'threat',
#   'principleof',
#   'thelema',
#   'exercising',
#   'true',
#   'putting',
#   'forth',
#   'verycomplex',
#   'picture',
#   'easy_answer',
#   'picture_leaf',
#   'roomfor',
#   'many',
#   'interpretationsit',
#   'quite_easy',
#   'see',
#   'example',
#   'oto',
#   'derivedout',
#   'dribble',
#   'faltering',
#   'masonry',
#   'purchased',
#   'clever',
#   'hucksterswith',
#   'ounce',
#   'courage',
#   'writing',
#   'ability',
#   'aid',
#   'ican',
#   'take',
#   'way',
#   'present',
#   'caliph',
#   'whose',
#   'feeblesupport',
#   'law',
#   'thelema',
#   'laughable',
#   'bestwould',
#   'thrown',
#   'order',
#   'speaking',
#   'way',
#   'think',
#   'notwhy',
#   'frater',
#   'see',
#   'perspective',
#   'interjectioni',
#   'using',
#   'example',
#   'illustration',
#   'show',
#   'may',
#   'express',
#   'thingsin',
#   'context',
#   'larger',
#   'work',
#   'true',
#   'significance',
#   'may_bequite',
#   'difficult',
#   'apprehend',
#   'firstso',
#   'may',
#   'oto',
#   'merlinus',
#   'please',
#   'look',
#   'oto',
#   'carefullyi',
#   'support',
#   'reusss',
#   'word',
#   'qualified',
#   'assessthem',
#   'critical',
#   'pomposity',
#   'member_ofthe',
#   'order',
#   'take',
#   'stand',
#   'allowed_continue',
#   'thenwhat',
#   'say',
#   'health',
#   'order',
#   'mean_thatthe',
#   'order',
#   'gone_soft',
#   'abandoned',
#   'moral_principle',
#   'ordoes',
#   'mean',
#   'strong',
#   'ability',
#   'let',
#   'ofuniversal',
#   'kinship',
#   'arise',
#   'shackled',
#   'dogmaticrequirement',
#   'shall',
#   'resolve',
#   'two',
#   'possibilitiesi',
#   'find',
#   'high',
#   'calibre',
#   'individual',
#   'associated',
#   'ordo_templi',
#   'orientisthey',
#   'often',
#   'quite',
#   'intelligent',
#   'sometimes',
#   'well_versed',
#   'arcaneor',
#   'usual',
#   'information',
#   'quite_often',
#   'artist',
#   'genius',
#   'met',
#   'longstanding',
#   'member',
#   'bay_area',
#   'many',
#   'orwere',
#   'heavily',
#   'involved',
#   'order',
#   'vouch',
#   'integrityof',
#   'organization',
#   'standsi',
#   'sometimes',
#   'questioned',
#   'policy',
#   'hymenaeus_beta',
#   'moment',
#   'followed',
#   'intuition',
#   'ive_found_little',
#   'stop',
#   'requestinga',
#   'second',
#   'initiation',
#   'different',
#   'oto_body',
#   'happily',
#   'participatingin',
#   'social',
#   'group',
#   'feast',
#   'initiation',
#   'come',
#   'know',
#   'gnosticmass',
#   'well_enough',
#   'taste',
#   'doesnt_make',
#   'authority',
#   'order',
#   'politics',
#   'explanation',
#   'howeveri',
#   'hypothesize',
#   'relay',
#   'understand',
#   'based',
#   'mylimited',
#   'contact',
#   'membersi',
#   'urge',
#   'take',
#   'word',
#   'merlinus',
#   'far',
#   'manyways',
#   'interpret',
#   'word',
#   'many_people',
#   'become_involved',
#   'withthe',
#   'order',
#   'feel_strongly',
#   'sanctity',
#   'personal',
#   'freedomand',
#   'preservation',
#   'individual',
#   'visioni',
#   'welcome_comment',
#   'issue',
#   'writing',
#   'responseto',
#   'post',
#   'threadinvoke',
#   'star_love',
#   'law',
#   'love_willi'],
#  ['kirlian_imaging',
#   'believe',
#   'faq_sciskeptics',
#   'nice_writeup',
#   'would',
#   'certainly_supportive',
#   'helping_build',
#   'device_connect',
#   'kvolt_supply',
#   'take',
#   'serious',
#   'look_aura'],
#  ['notion', 'heliocentric', 'even', 'galacticentric', 'either'],
#  ['following',
#   'report',
#   'turkey',
#   'eye',
#   'regional',
#   'role',
#   'ankara_turkey',
#   'apapril',
#   'find',
#   'last',
#   'paragraphturanist',
#   'although',
#   'premier',
#   'suleyman_demirel',
#   'criticized',
#   'ozals',
#   'oftenturanist',
#   'brash',
#   'call',
#   'turkish_influence',
#   'also',
#   'spokenturanist',
#   'swath',
#   'turkic_people',
#   'stretching',
#   'adriaticturanist',
#   'sea',
#   'great_wall',
#   'chinawho',
#   'demirel',
#   'think',
#   'fooling',
#   'seems',
#   'end',
#   'envisioned',
#   'panturkic',
#   'empire',
#   'balkan',
#   'caucasus_turkey',
#   'fascist',
#   'boastsare',
#   'preemptedi',
#   'would_suggest',
#   'turkey',
#   'let',
#   'world',
#   'feel',
#   'grey',
#   'wolf',
#   'teeth',
#   'andattempt',
#   'stretch',
#   'adriatic',
#   'china',
#   'turkey',
#   'cried',
#   'wolfjust',
#   'much'],
#  ['many',
#   'thanks_replied',
#   'appeal',
#   'info',
#   'drive',
#   'havewhich',
#   'rpmi',
#   'information',
#   'modify',
#   'use',
#   'bbc_computer',
#   'change',
#   'speed',
#   'rpmtried',
#   'also',
#   'change',
#   'component',
#   'recplay',
#   'section',
#   'allowfor',
#   'lower',
#   'data_rate',
#   'kbit',
#   'kbit',
#   'designed',
#   'alsochange',
#   'recording',
#   'current',
#   'allow',
#   'low',
#   'data',
#   'raterev',
#   'speedhopefully',
#   'sort',
#   'bad',
#   'quid',
#   'normally',
#   'quid',
#   'upwards',
#   'drive',
#   'jvc',
#   'mdp',
#   'series',
#   'drive'],
#  ['year_ago',
#   'almost',
#   'became',
#   'victim',
#   'squirted',
#   'fair_amount',
#   'inan',
#   'old',
#   'model',
#   'teletype',
#   'acting',
#   'turned',
#   'eruptionwhen',
#   'motor',
#   'starting',
#   'contact',
#   'broke',
#   'mighty',
#   'spectacular_almost',
#   'gotmy',
#   'eyebrow',
#   'singed',
#   'plastic',
#   'old',
#   'one',
#   'safety',
#   'glass',
#   'cover',
#   'theplaten',
#   'etc',
#   'flew',
#   'across',
#   'room',
#   'several_people',
#   'room',
#   'almost',
#   'hadheart',
#   'attack',
#   'beware',
#   'explosive',
#   'property',
#   'vapor'],
#  ['supreme_court',
#   'seems',
#   'disagree',
#   'stated',
#   'thatthe',
#   'people',
#   'term_art',
#   'refering',
#   'individual_right',
#   'andhave',
#   'explicitly_mentioned',
#   'second_amendment',
#   'examplei',
#   'quote',
#   'people',
#   'seems',
#   'term_art',
#   'employed',
#   'select_part',
#   'constitution',
#   'preamble',
#   'declares',
#   'constitution',
#   'ordained_established',
#   'people',
#   'second_amendment',
#   'protects_right',
#   'people_keep_bear',
#   'arm',
#   'supreme_court',
#   'uerdugouriquidez',
#   'furthermore',
#   'miller',
#   'decision',
#   'permitted',
#   'prosecutionfor',
#   'possession',
#   'sawedoff_shotgun',
#   'defense',
#   'notpresented',
#   'testimony',
#   'therefore',
#   'accepted',
#   'argument',
#   'thegovernment',
#   'weapon',
#   'military',
#   'value',
#   'held_thatthe',
#   'amendment',
#   'protected_individual_right',
#   'posse',
#   'militaryweapons',
#   'unfortunately',
#   'second_amendment',
#   'case',
#   'successfullygotten',
#   'court',
#   'fifty_year',
#   'however',
#   'change',
#   'theinterpretationfurthermore',
#   'appears',
#   'others_disagree',
#   'well',
#   'vi',
#   'conclusion',
#   'thus',
#   'inescapable',
#   'history',
#   'concept',
#   'wording',
#   'second_amendment',
#   'constitution_united_state',
#   'well',
#   'interpretation',
#   'every',
#   'major',
#   'commentator',
#   'court',
#   'first',
#   'halfcentury',
#   'ratifi',
#   'cation',
#   'indicates',
#   'protected_individual_right',
#   'private_citizen',
#   'carry',
#   'firearm',
#   'peaceful',
#   'manner',
#   'report_subcommittee',
#   'constitution_committee',
#   'judiciary_united_state',
#   'senate_congress',
#   'second_session',
#   'february',
#   'might',
#   'rightfully_ask',
#   'well',
#   'first',
#   'bit',
#   'aboutmilitias',
#   'meanwell',
#   'militia',
#   'historical_context',
#   'basically',
#   'mean',
#   'whole',
#   'theadult',
#   'male',
#   'country',
#   'indeed',
#   'code',
#   'still',
#   'definesmilitia',
#   'armed_men',
#   'age',
#   'militia',
#   'comprised',
#   'male_physically',
#   'capable_acting',
#   'concert_common',
#   'defense',
#   'men',
#   'expected',
#   'appear',
#   'bearing_arm',
#   'supplied',
#   'kind',
#   'common',
#   'use',
#   'time',
#   'supreme_court',
#   'united_state',
#   'miller',
#   'reason',
#   'phrase_explain',
#   'rationalebehind',
#   'amendment',
#   'depending',
#   'people',
#   'tobear',
#   'arm_defense',
#   'country',
#   'centralization',
#   'militarypower',
#   'could',
#   'ever_occur',
#   'would',
#   'permit',
#   'tyranny',
#   'short',
#   'thegovernment',
#   'would',
#   'remain',
#   'perpetually',
#   'fear',
#   'people',
#   'rather_thanthe',
#   'way',
#   'around',
#   'free_man_shall',
#   'ever_debarred',
#   'use',
#   'arm',
#   'strongest_reason',
#   'people_retain',
#   'right_keep_bear_arm',
#   'last_resort_protect',
#   'tyranny',
#   'government',
#   'thomas_jefferson',
#   'proposal',
#   'virginia',
#   'constitution',
#   'june',
#   'thomas_jefferson',
#   'paper',
#   'boyd',
#   'country',
#   'preserve',
#   'liberty',
#   'ruler',
#   'warned',
#   'time',
#   'time',
#   'people',
#   'preserve',
#   'spirit',
#   'resistance',
#   'let_take',
#   'arm',
#   'tree_liberty',
#   'must',
#   'refreshed',
#   'time',
#   'time',
#   'blood',
#   'patriot',
#   'tyrant',
#   'thomas_jefferson',
#   'letter',
#   'william',
#   'smith',
#   'jefferson',
#   'democracy',
#   'padover',
#   'standing_army',
#   'rule',
#   'people',
#   'must',
#   'disarmed',
#   'almost_every',
#   'kingdom_europe',
#   'supreme_power',
#   'america',
#   'enforce',
#   'unjust',
#   'law',
#   'sword',
#   'whole_body',
#   'people',
#   'armed',
#   'constitute',
#   'force',
#   'superior',
#   'band',
#   'regular_troop',
#   'pretense',
#   'raised',
#   'united_state',
#   'noah',
#   'webster',
#   'examination',
#   'leading',
#   'principle',
#   'federal_constitution',
#   'pamphlet',
#   'constitution_united_state',
#   'ford',
#   'may',
#   'disagree',
#   'second_amendment',
#   'wish',
#   'berepealed',
#   'please',
#   'pretend',
#   'isnt',
#   'itdoesnt',
#   'mean',
#   'say',
#   'might_argue',
#   'condition',
#   'havechanged',
#   'longer',
#   'present',
#   'cant',
#   'imagineit',
#   'awayi',
#   'could_fill',
#   'book',
#   'detailed',
#   'argumentation',
#   'many',
#   'alreadyhowever',
#   'none',
#   'anything',
#   'cryptography',
#   'let',
#   'getit',
#   'insist',
#   'discussing',
#   'please',
#   'intalkpoliticsguns',
#   'people',
#   'gladly',
#   'discus',
#   'matter',
#   'withyouperry',
#   'metzgerpmetzgershearsoncom'],
#  ['argue',
#   'gyroscope',
#   'etc',
#   'throughly',
#   'understandedthe',
#   'technique',
#   'countersteeringmeincluding',
#   'one',
#   'think_countersteer',
#   'waymethrough',
#   'corneredwell',
#   'way_decreasingradius',
#   'corner',
#   'anywaymaybe',
#   'riding',
#   'around',
#   'everdecreasing',
#   'circle_lie',
#   'whicheventually',
#   'lead',
#   'truthmethe',
#   'official_line',
#   'though',
#   'doubt',
#   'themefront',
#   'brake_applied',
#   'first',
#   'followed_rear_brake',
#   'idea',
#   'beingmethat',
#   'avoid_locking',
#   'rear_weight',
#   'transfer_take_place',
#   'though',
#   'unfortunately',
#   'official_line',
#   'one',
#   'youhave',
#   'adhere',
#   'want',
#   'get',
#   'full_licence',
#   'examinersguidelines',
#   'laid',
#   'government',
#   'basic',
#   'rider',
#   'educationcourses',
#   'choice_follow',
#   'surprise',
#   'none',
#   'therider',
#   'group',
#   'either',
#   'mag',
#   'bmf',
#   'make',
#   'much',
#   'noise',
#   'fact_thatthe',
#   'riding_test',
#   'requires',
#   'ride',
#   'three',
#   'foot',
#   'kerb',
#   'timein',
#   'order',
#   'pas_front',
#   'brake',
#   'must',
#   'applied',
#   'rear',
#   'thatyou',
#   'keep',
#   'looking_shoulder',
#   'time',
#   'instead',
#   'justwhen',
#   'justified',
#   'there',
#   'probably',
#   'cantthink',
#   'moment',
#   'riding_test',
#   'could',
#   'rejigged',
#   'bit',
#   'include',
#   'realworld',
#   'survival',
#   'skill',
#   'le',
#   'woefully',
#   'simplistic',
#   'crap',
#   'contains',
#   'accident',
#   'figureswould',
#   'imho',
#   'reduce',
#   'still',
#   'furtherdont',
#   'think',
#   'include',
#   'countersteering_knowledge',
#   'test',
#   'though'],
#  ['considering_buying',
#   'chevy',
#   'gmc',
#   'fullsize',
#   'pickup',
#   'extended_cab',
#   'opinion',
#   'vehicle',
#   'significant',
#   'problem',
#   'dick',
#   'grady',
#   'salem',
#   'usa',
#   'gradyworldstdcom',
#   'many_newsgroups',
#   'little',
#   'timei',
#   'bought',
#   'brand_new',
#   'chevrolet',
#   'extended_cab',
#   'lastmay',
#   'many',
#   'many',
#   'problem',
#   'see',
#   'earler',
#   'post',
#   'describesthe',
#   'situation',
#   'went',
#   'bbb',
#   'arbitration',
#   'ruled',
#   'chevroletmust',
#   'buy',
#   'back',
#   'get',
#   'one',
#   'stay_away',
#   'speedmanual',
#   'deep',
#   'low',
#   'first',
#   'gear',
#   'put',
#   'three',
#   'mytruck',
#   'far',
#   'mile',
#   'overdrive',
#   'either',
#   'startsrattling',
#   'hissing',
#   'loudly',
#   'way',
#   'fix',
#   'chevrolet',
#   'say',
#   'noise',
#   'characteristic',
#   'transmissionalso',
#   'planning_use',
#   'truck_tow',
#   'thegear',
#   'ratio',
#   'tranny',
#   'suck',
#   'steep_hill',
#   'get',
#   'mph',
#   'second_gear',
#   'rpm',
#   'yellow_line',
#   'shift',
#   'thirdthe',
#   'rpm',
#   'drop',
#   'begin',
#   'loose',
#   'speed',
#   'shouldpoint',
#   'put',
#   'gvw',
#   'truck',
#   'adetuned',
#   'motor',
#   'compared',
#   'one',
#   'put',
#   'light_duty',
#   'one',
#   'theydropped',
#   'compression_ratio',
#   'supposedly',
#   'engine',
#   'longevityreasons',
#   'light_duty',
#   'may',
#   'pull',
#   'better',
#   'truck',
#   'doesother',
#   'thing',
#   'gone_wrong',
#   'include',
#   'ventilation',
#   'fan',
#   'time',
#   'far',
#   'paint',
#   'spec',
#   'rust',
#   'embedded',
#   'paint',
#   'beingshipped',
#   'rail',
#   'covering',
#   'suspension',
#   'part',
#   'link',
#   'betweenstabilizer',
#   'control_arm',
#   'fell',
#   'offany',
#   'company',
#   'make',
#   'bad',
#   'individual',
#   'car',
#   'chevrolet',
#   'included',
#   'whatreally',
#   'bothered',
#   'way',
#   'reacted',
#   'made',
#   'attemptto',
#   'deal',
#   'except',
#   'tell',
#   'take',
#   'back',
#   'dealer',
#   'attempt',
#   'fix',
#   'one',
#   'time',
#   'bought',
#   'brand',
#   'newford',
#   'super',
#   'cab',
#   'automatic',
#   'neverbuy_another',
#   'chevrolet'],
#  ['sorry',
#   'thats',
#   'feature',
#   'icccm',
#   'specifies',
#   'app',
#   'set',
#   'title',
#   'obliged',
#   'bother',
#   'complain',
#   'app',
#   'writerwrite',
#   'doesnt_support',
#   'icccm',
#   'write_program',
#   'give',
#   'window_title',
#   'program',
#   'set',
#   'window_title',
#   'app_app',
#   'change',
#   'program',
#   'switch_back'],
#  ['dont',
#   'imagine_real',
#   'oldamiga',
#   'user',
#   'think',
#   'take_look',
#   'also',
#   'real',
#   'amiga',
#   'saw',
#   'imagine',
#   'theamiga',
#   'long_time_friend',
#   'home',
#   'andive_seen',
#   'action',
#   'bitmovie',
#   'riccioneitaly',
#   'italian',
#   'computer_graphic',
#   'contestmany',
#   'professional',
#   'using',
#   'studio',
#   'softimagefor',
#   'silicon_graphic',
#   'imagine_amiga',
#   'impressed',
#   'power',
#   'programssorry',
#   'ive_lost',
#   'posting',
#   'full_description',
#   'feature',
#   'great',
#   'programfor',
#   'information',
#   'give',
#   'look',
#   'compsysamigagraphicsrepresentative',
#   'activa',
#   'international',
#   'told',
#   'thatit',
#   'week',
#   'amiga',
#   'thatpc',
#   'mswindows',
#   'silicon',
#   'indigo',
#   'unix_version',
#   'developmentciaosergio'],
#  ['ive_ever',
#   'done',
#   'automatic',
#   'sitting',
#   'old',
#   'inthe_winter',
#   'light',
#   'heard_screeching',
#   'behind',
#   'managed',
#   'todart',
#   'left_turn',
#   'lane',
#   'sliding',
#   'jetta',
#   'wound',
#   'halfwhere',
#   'half',
#   'parked_car',
#   'beside',
#   'ive',
#   'neverhad',
#   'occasion',
#   'bike',
#   'imagine',
#   'would',
#   'eveneasier',
#   'could',
#   'slip',
#   'beside',
#   'car_front',
#   'giving',
#   'ganderat',
#   'mirror_light',
#   'give',
#   'time',
#   'get',
#   'clutchout',
#   'smoothly',
#   'notice',
#   'trouble',
#   'instead_waiting',
#   'thescreeching'],
#  ['dont_know_exact',
#   'coverage',
#   'state_canada',
#   'coveredby',
#   'tsn',
#   'maybe',
#   'espn',
#   'grab',
#   'coverage',
#   'dont_knowas',
#   'picksottawa',
#   'pick',
#   'mean',
#   'almost',
#   'alexander_daigle',
#   'hell',
#   'either',
#   'stay',
#   'traded',
#   'montreal_quebec',
#   'imo',
#   'wouldtake',
#   'kariya',
#   'alot',
#   'leadership',
#   'ncaa',
#   'far',
#   'inthe',
#   'world_championship',
#   'daigle',
#   'didnt',
#   'show',
#   'junior',
#   'teamsan',
#   'jose',
#   'get',
#   'kariyatampa',
#   'bay',
#   'either',
#   'russian',
#   'kozlov',
#   'think_thats',
#   'defenseman_rob',
#   'niedemeyer',
#   'probably',
#   'spelt',
#   'last_name',
#   'wrongbecause',
#   'expansion',
#   'wont',
#   'name',
#   'theblue',
#   'chip',
#   'prospect',
#   'chris',
#   'gratton',
#   'chris',
#   'pridham',
#   'swedish_player',
#   'cant_remember',
#   'namedraft',
#   'order',
#   'ottawa',
#   'san_jose_tampa_bay',
#   'south_florida_anahiem',
#   'south_florida_anahiem',
#   'hartford',
#   'edmonton',
#   'dallas',
#   'ranger',
#   'philadelphiathe',
#   'thru',
#   'pick',
#   'could_wrong',
#   'dont',
#   'standing',
#   'hereand',
#   'guessing',
#   'mind',
#   'top_notch',
#   'prospect',
#   'draft',
#   'kariya',
#   'leading',
#   'way',
#   'going'],
#  ['awst_brief',
#   'blurb_manned',
#   'lunar_exploration',
#   'conferncemay',
#   'crystal_city_virginia',
#   'auspex',
#   'aiaadoes',
#   'anyone_know',
#   'much',
#   'attendanyone',
#   'want'],
#  ['reported',
#   'canadian',
#   'paper',
#   'thursday_april',
#   'think',
#   'thesource',
#   'upi',
#   'dont_recall',
#   'certaini',
#   'understand',
#   'least_two',
#   'goverment',
#   'investigation',
#   'orderedso',
#   'may',
#   'learn',
#   'hearing',
#   'tough',
#   'call',
#   'without',
#   'investigation',
#   'thermal_imaging',
#   'storyholds',
#   'think',
#   'government',
#   'credable',
#   'courseparanoia',
#   'fan',
#   'wont',
#   'believe',
#   'result',
#   'anyway',
#   'theyhear',
#   'hear',
#   'also',
#   'like',
#   'see',
#   'autopsy',
#   'report',
#   'confirm',
#   'news',
#   'reportsthat',
#   'multiple',
#   'victim_found',
#   'shot_head',
#   'positionsinconsistent',
#   'fire_victim',
#   'simply',
#   'early',
#   'draw',
#   'conclusionseither',
#   'way',
#   'nasty',
#   'incident',
#   'tend',
#   'believe',
#   'governmentside'],
#  ['using',
#   'vmode',
#   'command',
#   'need',
#   'type',
#   'vmode',
#   'vesa',
#   'dosprompt',
#   'vmode',
#   'included',
#   'speedstar',
#   'used',
#   'vesa',
#   'modefor',
#   'autodesk_animator',
#   'pro'],
#  ['cad',
#   'setup',
#   'salegplb',
#   'local_bus_motherboard',
#   'use_simms',
#   'kmm',
#   'expansion_slot_bit',
#   'slot_bit_slot',
#   'weitek_coprocessor',
#   'socket',
#   'mhz_intel',
#   'cpu_mhz',
#   'weitek',
#   'math',
#   'coprocessorghost',
#   'local_bus_video_card',
#   'based',
#   'tseng_lab',
#   'chip_design',
#   'support',
#   'resolution',
#   'interlaced_noninterlaced',
#   'us',
#   'ramdac',
#   'allow',
#   'color_color',
#   'register',
#   'level',
#   'compatible',
#   'cga_ega_vga',
#   'mda',
#   'software_driver',
#   'available',
#   'symphony',
#   'autocad_autoshade',
#   'window_wordperfect',
#   'vesa',
#   'emulation',
#   'also',
#   'contained',
#   'card',
#   'local_bus_ide_controller',
#   'floppy_disk_controller',
#   'two',
#   'fully',
#   'configuarable',
#   'serial_port_parallel_port',
#   'game_port',
#   'used',
#   'setup',
#   'run',
#   'autocad',
#   'studio',
#   'combination',
#   'local_bus',
#   'weitek_coprocessor',
#   'made',
#   'fast',
#   'cad',
#   'modeling',
#   'work',
#   'weitek_coprocessor',
#   'cut',
#   'studio',
#   'render',
#   'time',
#   'half',
#   'sometimes',
#   'also',
#   'increase',
#   'redraws',
#   'regens',
#   'modeling',
#   'studio',
#   'autocad',
#   'everything',
#   'le_year_old',
#   'asking_shipping',
#   'whole_package',
#   'please_respond_via_email',
#   'thanks'],
#  ['relativist',
#   'would_like',
#   'answer_question',
#   'way',
#   'youphrase',
#   'question',
#   'make',
#   'unanswerable',
#   'concept',
#   'rightand_wrong',
#   'correctincorrect',
#   'truefalse',
#   'belong',
#   'thedomain',
#   'epistemological',
#   'rather',
#   'moral',
#   'question',
#   'make',
#   'nosense',
#   'ask',
#   'moral_position',
#   'right_wrong',
#   'although',
#   'islegitimate',
#   'ask',
#   'good',
#   'better',
#   'another',
#   'positionlet',
#   'illustrate',
#   'point',
#   'looking',
#   'psychological',
#   'derivativesof',
#   'epistemology',
#   'ethic',
#   'perception',
#   'motivation',
#   'respectivelyone',
#   'certainly',
#   'ask',
#   'percept',
#   'right',
#   'correct',
#   'trueveridical',
#   'wrong',
#   'incorrect',
#   'false',
#   'illusory',
#   'make_littlesense',
#   'ask',
#   'motive',
#   'true_false',
#   'hand',
#   'isstrange',
#   'ask_whether',
#   'percept',
#   'morally',
#   'good_evil',
#   'one',
#   'cancertainly',
#   'ask_question',
#   'motivestherefore',
#   'suggested',
#   'answer',
#   'simply_cant',
#   'consideredthey',
#   'assume',
#   'judge',
#   'correctness',
#   'moral',
#   'judgmentnow',
#   'problem',
#   'doublebarrelled',
#   'agree',
#   'withthe',
#   'first',
#   'part',
#   'rightness',
#   'moral_position',
#   'ameaningless',
#   'question',
#   'reason',
#   'stated',
#   'isirrelevant',
#   'alleged',
#   'implication',
#   'implication',
#   'thatone',
#   'feel',
#   'peace',
#   'better',
#   'war',
#   'certainly',
#   'makevalue',
#   'judgment',
#   'bad',
#   'better',
#   'best',
#   'without',
#   'asserting',
#   'correctnessof',
#   'positionsorry',
#   'lengthy',
#   'dismissal',
#   'short_answer',
#   'isthat',
#   'two',
#   'individual',
#   'grotesquely',
#   'disagree_moral',
#   'issueneither',
#   'right',
#   'correct_wrong',
#   'incorrect',
#   'simply',
#   'holddifferent',
#   'moral_value',
#   'feeling'],
#  ['wroteis',
#   'resource',
#   'available',
#   'consumer',
#   'comparing',
#   'makesand',
#   'model',
#   'automobile',
#   'truck',
#   'van',
#   'etc',
#   'survivability',
#   'acrash',
#   'different',
#   'severitiesalso',
#   'ive_found_little',
#   'objective',
#   'data',
#   'comparing',
#   'differentvehicles',
#   'handling',
#   'pickup',
#   'braking',
#   'expected',
#   'maintenance',
#   'etci',
#   'recall_year_ago',
#   'consumer_report',
#   'annual_buyer_guide',
#   'much',
#   'moreinformative',
#   'aspect',
#   'nowthanks',
#   'reply',
#   'someone',
#   'looked',
#   'little',
#   'found',
#   'whati',
#   'looking',
#   'april',
#   'magazine',
#   'thingsdespite',
#   'recent_article',
#   'rating',
#   'looked_pretty_good',
#   'forrelative',
#   'comparison_purpose',
#   'unfortunately',
#   'crash_test',
#   'comparisonsdidnt',
#   'include',
#   'half',
#   'car',
#   'comparinganybody',
#   'know',
#   'honda_civic',
#   'hatchback',
#   'toyota_tercel',
#   'fare',
#   'inan',
#   'accident'],
#  ['explanation',
#   'federal_law_enforcement_official',
#   'whathappened',
#   'waco',
#   'another_example',
#   'survivor',
#   'writing',
#   'thehistory_book',
#   'put',
#   'best',
#   'bad',
#   'light',
#   'dave_feustel_nmyi_feustelnetcomcom'],
#  ['anybody',
#   'generated',
#   'server',
#   'window',
#   'willingto',
#   'share',
#   'config_file',
#   'trick',
#   'necessary',
#   'make_workthanks',
#   'information'],
#  ['patient',
#   'sore',
#   'shoulder',
#   'crashing',
#   'wallthe',
#   'card',
#   'give',
#   'time',
#   'need',
#   'come',
#   'aroundhe',
#   'full',
#   'time',
#   'centerfielderhe',
#   'however',
#   'steal',
#   'often',
#   'year',
#   'hittingcleanup'],
#  ['according',
#   'previous_poster',
#   'one',
#   'seek',
#   'doctorsassistance',
#   'injection',
#   'sumatriptin',
#   'spdoesnt',
#   'one',
#   'inject',
#   'oneself',
#   'immediately',
#   'upon',
#   'onsetof',
#   'migraine'],
#  ['way',
#   'connect',
#   'powerbook',
#   'mac_iisi',
#   'personal',
#   'laserwriterls',
#   'necessarily',
#   'silmultaneoulsy',
#   'print',
#   'either',
#   'iisior',
#   'file',
#   'share',
#   'iisi',
#   'pbi',
#   'know',
#   'get',
#   'expensive',
#   'upgrade',
#   'cant',
#   'affordthat'],
#  ['would',
#   'believe',
#   'letter',
#   'macweek_week',
#   'fromone',
#   'hardware',
#   'type',
#   'digital_eclipse',
#   'say',
#   'runtests',
#   'component',
#   'see',
#   'perform',
#   'theupgraded',
#   'speed',
#   'desi',
#   'replaces',
#   'one',
#   'thatdo'],
#  ['proof',
#   'entire',
#   'private_sector',
#   'vastly',
#   'inefficientblue',
#   'cross',
#   'government',
#   'health_insurance',
#   'provideroopsads',
#   'magazine',
#   'deleted',
#   'save',
#   'earth'],
#  ['david_karr',
#   'tue_apr_gmt_wibbled',
#   'article',
#   'aprbnrca',
#   'regard',
#   'pub',
#   'brawl',
#   'might',
#   'history',
#   'thing',
#   'biker',
#   'doesnt_make',
#   'reasonable',
#   'person',
#   'even',
#   'dod',
#   'might',
#   'object',
#   'joining',
#   'know',
#   'history',
#   'thing',
#   'mentioned_article',
#   'present_irrelevant',
#   'detail',
#   'got',
#   'drinking_money',
#   'cant_say',
#   'exactly_fault',
#   'sit',
#   'look_like',
#   'seeing',
#   'result',
#   'either',
#   'law',
#   'going',
#   'way',
#   'hand_shoddy',
#   'journalism',
#   'law',
#   'want_attach',
#   'string_spend',
#   'settlement',
#   'put_money',
#   'trust',
#   'dont',
#   'would_assume',
#   'perfectly_legitimate',
#   'drink_away',
#   'though_wouldnt',
#   'spend',
#   'way',
#   'david_karr',
#   'karrcscornelleduwe',
#   'heard_newspaper',
#   'article',
#   'journalist',
#   'editorsalways',
#   'pick',
#   'interesting',
#   'sensational',
#   'fact',
#   'ourfacts',
#   'get',
#   'way',
#   'good',
#   'story',
#   'must',
#   'noticed',
#   'howmotorcyclists',
#   'get',
#   'treated_press',
#   'thrive',
#   'hysteriaignorance',
#   'sensationalism',
#   'oneupmanship',
#   'unfortunately',
#   'theresnot',
#   'enough',
#   'salt',
#   'keep',
#   'taking',
#   'pinch',
#   'ofnick',
#   'cynical',
#   'old',
#   'biker_dod_concise_oxford',
#   'leaky',
#   'new',
#   'gearboxmlud'],
#  ['reading',
#   'folk',
#   'thing',
#   'illegally',
#   'parked_car',
#   'made',
#   'mewonder',
#   'who_going',
#   'carry',
#   'cinder_block',
#   'bike',
#   'ready_serious',
#   'damage',
#   'key',
#   'carving',
#   'etc',
#   'cage',
#   'ihad',
#   'ideachain',
#   'lube',
#   'isnt',
#   'chain',
#   'anymore',
#   'seemsmore',
#   'reasonable',
#   'permanent_damage',
#   'lot',
#   'work',
#   'getoff',
#   'dont',
#   'ask',
#   'know',
#   'use',
#   'anywhere',
#   'windshieldthe',
#   'door',
#   'handle',
#   'keyhole',
#   'etc',
#   'nasty',
#   'mood',
#   'inits',
#   'raining'],
#  ['zeno',
#   'paradox',
#   'resolved',
#   'showing',
#   'integration',
#   'infiniteseries',
#   'decreasing',
#   'term',
#   'sum',
#   'finite',
#   'resultwell',
#   'suppose',
#   'probe',
#   'emitting',
#   'radiation',
#   'constant',
#   'frequency',
#   'wassent',
#   'towards',
#   'black_hole',
#   'got',
#   'closer',
#   'event_horizon',
#   'thered',
#   'shift',
#   'would',
#   'keep',
#   'increasing',
#   'period',
#   'would',
#   'get',
#   'longer',
#   'longerbut',
#   'would',
#   'never',
#   'stop',
#   'observer',
#   'would',
#   'observe',
#   'probe',
#   'actuallyreaching',
#   'event_horizon',
#   'detected',
#   'energy',
#   'probe',
#   'would',
#   'keepdecreasing',
#   'wouldnt',
#   'vanish',
#   'expt',
#   'never',
#   'quite',
#   'reach',
#   'zeroi',
#   'guess',
#   'probably_doesnt_make',
#   'thing',
#   'clear',
#   'hopefullyyou',
#   'get',
#   'general',
#   'idea',
#   'maybe'],
#  ['looking',
#   'package',
#   'take',
#   'input',
#   'setof',
#   'geometric',
#   'object',
#   'defined',
#   'union',
#   'convex',
#   'polytopesspecified',
#   'manner',
#   'say',
#   'inequality',
#   'equalitiesand',
#   'determines',
#   'reasonable',
#   'form',
#   'thing',
#   'likeintersections',
#   'union_etc',
#   'etcdoes',
#   'anyone_know',
#   'find',
#   'thing'],
#  ['dear',
#   'time',
#   'try',
#   'remember',
#   'chemistry',
#   'let_see',
#   'ican_find',
#   'formula',
#   'somewhere',
#   'dim',
#   'recess',
#   'mindsounds',
#   'gear',
#   'fume',
#   'overheated',
#   'oil',
#   'unmistakable',
#   'stench',
#   'ofthe',
#   'nasal',
#   'chromatograph',
#   'knew',
#   'double_bond',
#   'nowhow',
#   'shall',
#   'show',
#   'ascii',
#   'mek',
#   'acetone',
#   'othe',
#   'hydrogen',
#   'shown',
#   'represents',
#   'double_bond',
#   'mek',
#   'amethyl',
#   'one_side',
#   'ethyl',
#   'acetonehas',
#   'two',
#   'methyl',
#   'acetone',
#   'methyl',
#   'ethyl',
#   'ketone',
#   'insteadis',
#   'dimethyl',
#   'ketone',
#   'solvent',
#   'similar',
#   'property',
#   'thinkthat',
#   'mek',
#   'may',
#   'little_le',
#   'flammable',
#   'lot_worse',
#   'breatheits',
#   'lot_harder',
#   'buy',
#   'mek',
#   'use',
#   'acetonenail',
#   'polish',
#   'remover',
#   'consists',
#   'almost_entirely',
#   'acetone',
#   'buysome',
#   'workshop',
#   'get',
#   'cheapest',
#   'moreexpensive',
#   'kind',
#   'oil',
#   'perfume',
#   'dont_need'],
#  ['archivename',
#   'recautospartthe',
#   'automotive',
#   'article',
#   'archive_serverthe',
#   'automotive',
#   'archive_server',
#   'process',
#   'rehostedand',
#   'presently_available'],
#  ['nhls',
#   'alltime',
#   'leader',
#   'goal',
#   'point',
#   'end_ofthe',
#   'season',
#   'much',
#   'thanks',
#   'joseph',
#   'achkarcarlnotes',
#   'active_player',
#   'player_scored',
#   'least',
#   'onepoint',
#   'past_season',
#   'point',
#   'leader_follow',
#   'goal',
#   'leadersif',
#   'find',
#   'mistake',
#   'please_send',
#   'emailall',
#   'time',
#   'nhl',
#   'leading',
#   'goal_scorer',
#   'denotes_active',
#   'player',
#   'gordie_howe',
#   'dethfd',
#   'wayne_gretzky_edmla',
#   'marcel_dionne',
#   'detlanyr_phil',
#   'esposito_chibosnyr',
#   'bobby_hull',
#   'chiwpghfd',
#   'mike_gartner_wshminnyr',
#   'mike_bossy',
#   'nyi',
#   'guy_lafleur',
#   'mtlnyrque',
#   'johnny_bucyk',
#   'detbos',
#   'maurice_richard',
#   'mtl',
#   'stan_mikita',
#   'chi',
#   'frank_mahovlich',
#   'tordetmtl',
#   'michel_goulet',
#   'quechi',
#   'jari_kurri',
#   'edmla',
#   'bryan_trottier',
#   'nyipit',
#   'gilbert_perreault',
#   'buf',
#   'jean_beliveau',
#   'mtl',
#   'lanny_mcdonald',
#   'torcolcgy',
#   'jean_ratelle',
#   'nyrbos',
#   'norm_ullman',
#   'dettor',
#   'dino_ciccarelli',
#   'minwshdet',
#   'darryl_sittler',
#   'torphidet',
#   'mario_lemieux_pit',
#   'glenn_anderson',
#   'edmtor',
#   'alex_delvecchio',
#   'det',
#   'mark_messier_edmnyr',
#   'dale_hawerchuk_wpgbuf',
#   'rick_middleton',
#   'nyrbos',
#   'steve_yzerman',
#   'det',
#   'peter_stastny',
#   'quenj',
#   'rick_vaive',
#   'vantorchibuf',
#   'joe_mullen',
#   'stlcgypit',
#   'yvan_cournoyer',
#   'mtl',
#   'dave_taylor',
#   'steve_shutt',
#   'mtlla',
#   'denis_savard_chimtl',
#   'bill_barber_phi',
#   'brian_propp_phibosmin',
#   'gary_unger',
#   'tordetstlatllaedm',
#   'rod_gilbert',
#   'nyr',
#   'steve_larmer',
#   'chi',
#   'john_ogrodnick',
#   'detquenyr',
#   'active_player',
#   'bernie_nicholls',
#   'lanyredmnj',
#   'pat_lafontaine',
#   'nyibuf',
#   'brian_bellow',
#   'minmtl_dave_andreychuk',
#   'buftor',
#   'tim_kerr_phinyrhfd',
#   'bobby_smith',
#   'minmtl',
#   'brett_hull_cgystl',
#   'luc_robitaille',
#   'mike_foligno',
#   'detbuftor',
#   'dave',
#   'christian_wpgwshbosstlchi',
#   'paul_coffey_edmpitladet',
#   'brent_sutter',
#   'nyichi',
#   'pat_verbeek',
#   'njhfd',
#   'ron_francis_hfdpit',
#   'cam_neely',
#   'vanbos',
#   'ray_bourque_bos',
#   'bob_carpenter',
#   'wshnyrlabostor',
#   'brent_ashton',
#   'vancolnjminquedetwpgboscgy',
#   'doug_gilmour_stlcgytor',
#   'rick_tocchet',
#   'phipit',
#   'kevin_dineen_hfdphi',
#   'tomas_sandstrom',
#   'nyrla',
#   'dale_hunter_quewsh',
#   'ryan_walter',
#   'wshmtlvan',
#   'brian_mullen',
#   'wpgnyrsjnyi_olczyk',
#   'chitorwpgnyr',
#   'kirk_muller',
#   'njmtl',
#   'joe_nieuwendyk',
#   'cgy',
#   'jimmy_carson',
#   'laedmdet',
#   'time',
#   'nhl',
#   'scoring',
#   'leader',
#   'denotes_active',
#   'player',
#   'wayne_gretzky_edmla',
#   'gordie_howe',
#   'dethfd',
#   'marcel_dionne',
#   'detlanyr_phil',
#   'esposito_chibosnyr',
#   'stan_mikita',
#   'chi',
#   'bryan_trottier',
#   'nyipit',
#   'johnny_bucyk',
#   'detbos',
#   'guy_lafleur',
#   'mtlnyrque',
#   'gilbert_perreault',
#   'buf',
#   'alex_delvecchio',
#   'det',
#   'jean_ratelle',
#   'nyrbos',
#   'mark_messier_edmnyr',
#   'norm_ullman',
#   'dettor',
#   'peter_stastny',
#   'quenj',
#   'jean_beliveau',
#   'mtl',
#   'dale_hawerchuk_wpgbuf',
#   'bobby_clarke',
#   'phi',
#   'paul_coffey_edmpitladet',
#   'denis_savard_chimtl',
#   'jari_kurri',
#   'edmla',
#   'mario_lemieux_pit',
#   'bobby_hull',
#   'chiwpghfd',
#   'bernie_federko',
#   'stl',
#   'mike_bossy',
#   'nyi',
#   'michel_goulet',
#   'quechi',
#   'darryl_sittler',
#   'torphidet',
#   'mike_gartner_wshminnyr',
#   'frank_mahovlich',
#   'tordetmtl',
#   'ray_bourque_bos',
#   'dave_taylor',
#   'denis_potvin',
#   'nyi',
#   'henri_richard',
#   'mtl',
#   'steve_yzerman',
#   'det',
#   'bobby_smith',
#   'minmtl',
#   'rod_gilbert',
#   'nyr',
#   'glenn_anderson',
#   'edmtor',
#   'lanny_mcdonald',
#   'torcolcgy',
#   'rick_middleton',
#   'nyrbos',
#   'dave',
#   'keon',
#   'torhfd',
#   'ron_francis_hfdpit',
#   'bernie_nicholls',
#   'lanyredmnj',
#   'brian_propp_phibosmin',
#   'andy',
#   'bathgate',
#   'nyrtordetpit',
#   'maurice_richard',
#   'mtl_larry',
#   'robinson',
#   'mtlla',
#   'dino_ciccarelli',
#   'minwshdet',
#   'steve_larmer',
#   'chi_joe',
#   'mullen_stlcgypit',
#   'bobby_orr',
#   'boschi',
#   'brad_park',
#   'nyrbosdet',
#   'butch_goring',
#   'lanyibos',
#   'bill_barber_phi',
#   'dennis',
#   'maruk',
#   'calclewshmin',
#   'ivan',
#   'boldirev',
#   'boscalchiatlvandet',
#   'yvan_cournoyer',
#   'mtl',
#   'dean',
#   'prentice',
#   'nyrbosdetpitmin',
#   'ted',
#   'lindsay',
#   'detchi',
#   'tom',
#   'lysiak',
#   'atlchi',
#   'dale_hunter_quewsh',
#   'john_tonelli',
#   'nyicgylachique',
#   'jacques',
#   'lemaire',
#   'mtl_larry',
#   'murphy',
#   'lawshminpit',
#   'john_ogrodnick',
#   'detquenyr',
#   'doug',
#   'wilson',
#   'chisj',
#   'doug_gilmour_stlcgytor',
#   'red',
#   'kelly',
#   'dettor',
#   'pierre',
#   'larouche',
#   'pitmtlhfdnyr',
#   'bernie',
#   'geoffrion',
#   'mtlnyr',
#   'steve_shutt',
#   'mtlla',
#   'phil_housley',
#   'bufwpg',
#   'wilf',
#   'paiment',
#   'kccoltorquenyrbufpit',
#   'peter',
#   'mcnab',
#   'bufbosvannj',
#   'brian_bellow',
#   'minmtl_dave_andreychuk',
#   'buftor',
#   'pit',
#   'martin',
#   'detboschivan',
#   'pat_lafontaine',
#   'nyibuf',
#   'ken',
#   'linesman',
#   'phiedmbos',
#   'gary_unger',
#   'tordetstlatllaedm',
#   'ken',
#   'hodgesr',
#   'chibosnyr',
#   'neal',
#   'broten_min',
#   'wayne_cashman',
#   'bos',
#   'rick_vaive',
#   'vantorchibuf',
#   'borje_salming',
#   'tordet',
#   'jean',
#   'pronovost',
#   'pitatlwsh',
#   'peter',
#   'mahovlich',
#   'detmtlpit',
#   'dave',
#   'christian_wpgwshbosstlchi',
#   'rick',
#   'kehoe',
#   'torpit',
#   'rick',
#   'macleish',
#   'phihfdpitdet',
#   'thomas_steen',
#   'wpg',
#   'active_player',
#   'macinnis',
#   'cgy',
#   'luc_robitaille',
#   'mike_foligno',
#   'detbuftor',
#   'brent_sutter',
#   'nyichi',
#   'mark',
#   'howe',
#   'hfdphidet',
#   'kirk_muller',
#   'njmtl',
#   'tim_kerr_phinyrhfd',
#   'adam_oates',
#   'detstlbos',
#   'randy',
#   'carlyle',
#   'torpitwpg',
#   'ryan_walter',
#   'wshmtlvan',
#   'pat_verbeek',
#   'njhfd',
#   'brent_ashton',
#   'vancolnjminquedetwpgboscgy',
#   'bob_carpenter',
#   'wshnyrlabostor',
#   'brian_mullen',
#   'wpgnyrsjnyi_olczyk',
#   'chitorwpgnyr',
#   'kelly_kisio',
#   'detnyrsj',
#   'brett_hull_cgystl',
#   'rick_tocchet',
#   'phipit',
#   'dan',
#   'quinn',
#   'cgypitvanstlphimin',
#   'scott_stevens',
#   'wshstlnj',
#   'tomas_sandstrom',
#   'nyrla',
#   'tom',
#   'fergus',
#   'bostorvan',
#   'dave',
#   'babych',
#   'wpghfdvan',
#   'mike',
#   'ridley',
#   'nyrwsh',
#   'laurie',
#   'boschman',
#   'toredmwpgnjott',
#   'keith',
#   'acton',
#   'mtlminedmphi',
#   'murray_craven',
#   'detphihfd',
#   'kevin_dineen_hfdphi',
#   'rob_ramage',
#   'colstlcgytormintb',
#   'mike',
#   'krushelnyski',
#   'bosedmlator',
#   'gary_suter',
#   'cgy',
#   'pierre_turgeon',
#   'bufnyi',
#   'troy_murray',
#   'chiwpg',
#   'cam_neely',
#   'vanbos',
#   'geoff_courtnall',
#   'bosedmwshstlvan',
#   'vincent_damphousse',
#   'toredmmtl',
#   'jimmy_carson',
#   'laedmdet',
#   'peter_zezel',
#   'phistlwshtor',
#   'guy_carbonneau',
#   'mtl',
#   'mark_osborne',
#   'detnyrtorwpg',
#   'chris_chelios',
#   'mtlchi',
#   'dave_poulin',
#   'phibos',
#   'ray_ferraro',
#   'hfdnyi',
#   'rus',
#   'courtnall',
#   'tormtlmin',
#   'joe_nieuwendyk',
#   'cgy',
#   'john_maclean'],
#  ['belongs',
#   'compwindowsxiunix',
#   'ive_redirected',
#   'followupsi',
#   'know',
#   'fact',
#   'eisa_version',
#   'orchid_prodesigner',
#   'iisworks',
#   'however',
#   'eisa',
#   'svga_card',
#   'likely',
#   'waste',
#   'moneywhen',
#   'xfree',
#   'come',
#   'support',
#   'accelerated',
#   'chipsets',
#   'isaeisa',
#   'vlb',
#   'supportedthe',
#   'important_question',
#   'chipsets_supported',
#   'busis',
#   'basically',
#   'irrelevent',
#   'compatibility',
#   'issuedavid',
#   'wexelblat_dwexmtgzfsattcom',
#   'fax',
#   'att_bell_laboratory',
#   'laurel',
#   'ave',
#   'middletown',
#   'xfree',
#   'request',
#   'addressed',
#   'xfreephysicssuozau'],
#  ['anyone_experience',
#   'replacement',
#   'comm',
#   'driver',
#   'windowscalled',
#   'turbocomm',
#   'read',
#   'pcmag',
#   'apr',
#   'interestedbut',
#   'willing',
#   'shell_buck',
#   'company',
#   'want_try',
#   'itout',
#   'supposedly',
#   'eleminates',
#   'problem_occur',
#   'high',
#   'speedfile',
#   'transfer_disk',
#   'access',
#   'made',
#   'another',
#   'program',
#   'running',
#   'sametime',
#   'anyone',
#   'procons',
#   'product',
#   'would_interested_hear',
#   'please_email_address',
#   'give',
#   'thanks'],
#  ['counterpoint',
#   'sawatts',
#   'per',
#   'channelvery',
#   'warm',
#   'tube',
#   'sound_great',
#   'warming',
#   'cdsexcellent',
#   'shape'],
#  ['youre_blowing',
#   'smoke_qualcomm',
#   'want_sell',
#   'nice_lucrative',
#   'overseasmarkets',
#   'like',
#   'japan',
#   'government',
#   'told',
#   'dont',
#   'encryptionif',
#   'ever',
#   'hope_export',
#   'technology',
#   'reason_cdma',
#   'doesnthave',
#   'encryption_gmen',
#   'came_aknocking',
#   'qualcomms',
#   'doorits',
#   'qualcomm_doesnt',
#   'think',
#   'market_digital',
#   'cellularis',
#   'big_enough_international',
#   'traffic',
#   'armsregulations',
#   'againif',
#   'dont_believe',
#   'call',
#   'qualcomm',
#   'ask',
#   'dont',
#   'throwout',
#   'conspicracy',
#   'theory',
#   'least',
#   'dont',
#   'scicryptthere',
#   'arewhole',
#   'newsgroups',
#   'devoted',
#   'kind',
#   'uninformed',
#   'claptraphah',
#   'theyre',
#   'much_expensive',
#   'besides',
#   'drug',
#   'dealercan',
#   'afford',
#   'rolex',
#   'mercedes',
#   'darn_well',
#   'afford',
#   'cylink',
#   'phonesno',
#   'cylink_sell',
#   'phone_theyre_willing',
#   'make',
#   'differentstuff',
#   'domestic',
#   'use',
#   'export_qualcomm',
#   'isnt_cylink',
#   'makesmoneythats',
#   'capitalism',
#   'comradesomeone',
#   'someone',
#   'think',
#   'easy',
#   'areyou',
#   'whining_net',
#   'instead',
#   'getting_butt',
#   'gear',
#   'writingit',
#   'name',
#   'would',
#   'become',
#   'known',
#   'loved',
#   'dozen',
#   'wouldrequire',
#   'actual',
#   'effort'],
#  ['looking',
#   'exact_address',
#   'symantec',
#   'coporatoin',
#   'distributes',
#   'norton_desktop_window',
#   'softwarethe',
#   'information',
#   'looking',
#   'ismail',
#   'addressphone',
#   'numberfax',
#   'numberemail',
#   'addressthanks',
#   'advance'],
#  ['trying',
#   'choose',
#   'resistor',
#   'tolerance',
#   'better',
#   'need',
#   'trimmer',
#   'screen',
#   'device',
#   'cant',
#   'made',
#   'adding',
#   'resitors',
#   'value',
#   'parallel',
#   'since',
#   'smaller',
#   'device',
#   'error',
#   'cope',
#   'choicesa',
#   'live',
#   'error',
#   'tolerance',
#   'device',
#   'low',
#   'circuit_low',
#   'sensitivity',
#   'designsb',
#   'buy',
#   'resistor',
#   'better',
#   'tolerance',
#   'vishaydalec',
#   'use',
#   'trimmer',
#   'sot',
#   'selectontest'],
#  ['reason',
#   'limited',
#   'two',
#   'mentioned',
#   'arent_really',
#   'atthe',
#   'point',
#   'along',
#   'suv',
#   'spectrum',
#   'mention',
#   'price',
#   'rangehow',
#   'explorer',
#   'trooper',
#   'blazer',
#   'montero',
#   'budgetallows',
#   'land_cruiser',
#   'bear_mind',
#   'suv',
#   'purchased',
#   'never',
#   'venture',
#   'offroadcarefully',
#   'weigh',
#   'tradeoff',
#   'comfort',
#   'offroad',
#   'performancewhen',
#   'choosing',
#   'one',
#   'realistically',
#   'decide_whether',
#   'youll',
#   'actuallymake',
#   'enough',
#   'use',
#   'offroadability',
#   'sacrifice',
#   'theonroad',
#   'comfortjohn'],
#  ['anything',
#   'bill_clinton',
#   'janett',
#   'reno',
#   'started',
#   'whole',
#   'shenanigan',
#   'first_place',
#   'disclaimer_opinion_expressed_mine',
#   'employer'],
#  ['curious', 'would', 'clipper_chip', 'system', 'handleconference', 'call'],
#  ['dont_worry',
#   'theyll',
#   'drop',
#   'like',
#   'hot',
#   'potato',
#   'make_claim',
#   'theyll',
#   'make',
#   'filing',
#   'claim',
#   'pain',
#   'end',
#   'leave',
#   'lurchmore',
#   'geico',
#   'funded',
#   'company_developed',
#   'lidar',
#   'local',
# ...
#   'team',
#   'would',
#   'win',
#   'thetiebreaker',
#   'therefore',
#   'better',
#   'record',
#   'even_though',
#   'teamshad',
#   'number',
#   'point',
#   'didnt_understand',
#   'post',
#   'rexmaybe',
#   'back',
#   'read',
#   'slowly',
#   'keith_kellerlets_rangerslets_quakerskkellermailsasupenneduivy',
#   'league_champ'],
#  ['environment_macharch',
#   'sparcsun_ipx',
#   'sunos_patchlevel',
#   'motif_bring',
#   'server',
#   'using_startx',
#   'usrbinxxsun_following',
#   'sequence',
#   'action_crash',
#   'server_sigpipe',
#   'errno_xinit',
#   'report_connexion',
#   'server',
#   'lost',
#   'problem',
#   'well_graphic_card',
#   'come',
#   'ipx_fixed_problem',
#   'apply',
#   'sungxuu_part',
#   'patch_patch',
#   'also',
#   'used',
#   'file',
#   'perhaps',
#   'didnt',
#   'apply',
#   'one',
#   'came',
#   'patch_jeff',
#   'jeff',
#   'boote',
#   'bootencarucaredu',
#   'scientific_computing',
#   'division',
#   'nothing',
#   'good_bad',
#   'national_center_atmospheric_research',
#   'thinking',
#   'make',
#   'boulder',
#   'hamlet',
#   'thanx',
#   'jeff',
#   'youre',
#   'lifesaver',
#   'imported',
#   'new',
#   'sun',
#   'emulator',
#   'came',
#   'inwith',
#   'patch',
#   'problem',
#   'since',
#   'disappearedthanx',
#   'der',
#   'schoene',
#   'mouse',
#   'help'],
#  ['good',
#   'let_look',
#   'section',
#   'theyll',
#   'prove',
#   'pointnote',
#   'doesnt_affect',
#   'concealed_carry',
#   'look',
#   'theword',
#   'except',
#   'always',
#   'help',
#   'read',
#   'law',
#   'commenting',
#   'onitwould',
#   'prudent',
#   'storekeeper',
#   'carry_concealed',
#   'someone',
#   'athome',
#   'note',
#   'legal',
#   'lot',
#   'common',
#   'people',
#   'qualifyfor',
#   'one',
#   'otherandy'],
#  ['cjackson',
#   'glad_know',
#   'none',
#   'judgemental',
#   'little_shit',
#   'hascjackson',
#   'riddendriven',
#   'tired',
#   'sleepy',
#   'hungover',
#   'angry',
#   'distractedcjackson',
#   'last_year',
#   'might',
#   'guiltysome',
#   'notso',
#   'judgmental',
#   'little_shit',
#   'dont',
#   'driveride',
#   'wereimpaired',
#   'stopped',
#   'sort_thing',
#   'good_friend',
#   'ofmine_got',
#   'killed_drunk_driver',
#   'failed',
#   'stop',
#   'red',
#   'anddrove',
#   'side',
#   'volvo',
#   'caddythen',
#   'suspect_responsible',
#   'adult',
#   'net',
#   'dontbother',
#   'posting',
#   'flame_war',
#   'recmotocjackson',
#   'justification_taking_away',
#   'individual',
#   'freedomcjackson',
#   'guise',
#   'public_safety',
#   'thomas',
#   'jeffersonhe',
#   'also',
#   'owned_slave',
#   'kept',
#   'forced',
#   'concubine',
#   'enoughresources',
#   'wanted',
#   'without_fear_reprisal',
#   'againhe',
#   'also',
#   'smoked_dope'],
#  ['came',
#   'using',
#   'final_regular_season',
#   'stats',
#   'find',
#   'april_edition',
#   'usa',
#   'todaytry',
#   'see',
#   'come',
#   'adam_oates',
#   'bruin_pt',
#   'teemu_selanne',
#   'jet_pt',
#   'alexander_mogilny',
#   'sabre_pt',
#   'pavel_bure',
#   'canuck',
#   'pt',
#   'vincent_damphousse',
#   'canadian_pt',
#   'dave_andreychuk',
#   'mapleleafs',
#   'pt',
#   'phil_housley',
#   'jet_pt',
#   'paul_coffey',
#   'redwing_pt',
#   'sergei_fedorov',
#   'redwing_pt',
#   'andy_moog',
#   'bruin_pt',
#   'infrate',
#   'capitials',
#   'pt',
#   'patrick_roy',
#   'canadian_pt',
#   'macinnis',
#   'flame',
#   'pt',
#   'dennis',
#   'savard',
#   'canadian_pt',
#   'calle_johansson',
#   'capital',
#   'pt',
#   'yuri_khmylev',
#   'sabre_pt',
#   'richard_smehlik',
#   'sabre_pt',
#   'total',
#   'point',
#   'pt'],
#  ['foot_switch',
#   'sale',
#   'theyre',
#   'great',
#   'guitaramps',
#   'keyboard',
#   'diameter',
#   'socable',
#   'like',
#   'make_offer',
#   'knowsjason'],
#  ['really',
#   'think',
#   'comparing_apple_orange',
#   'nobody',
#   'disputesthat',
#   'big',
#   'feature',
#   'question',
#   'individual',
#   'need',
#   'power',
#   'sale',
#   'window',
#   'answer_thatquestion',
#   'next',
#   'question',
#   'even',
#   'want',
#   'run',
#   'osand',
#   'big',
#   'monster',
#   'machine',
#   'run',
#   'diverseset',
#   'application',
#   'run',
#   'allow',
#   'productviely',
#   'mywork',
#   'local_computer_store',
#   'answer',
#   'onei_think',
#   'comparison',
#   'need',
#   'thisis',
#   'new',
#   'battle',
#   'line_drawn',
#   'window',
#   'wonthe',
#   'single_user',
#   'war',
#   'next',
#   'one',
#   'client',
#   'serverwar',
#   'entry',
#   'unix',
#   'netware',
#   'granted',
#   'os',
#   'eventually',
#   'scaled',
#   'beattractive',
#   'single_user',
#   'probably',
#   'phase',
#   'iiof',
#   'war',
#   'win',
#   'marketplace',
#   'tell',
#   'sure',
#   'fun_watching',
#   'arguing',
#   'thothx',
#   'dave'],
#  ['havent',
#   'following',
#   'previous',
#   'hr',
#   'two',
#   'sawlive',
#   'would',
#   'rick',
#   'monday',
#   'bury',
#   'expo',
#   'championship',
#   'hit',
#   'steve',
#   'rogers',
#   'rhp',
#   'primarily',
#   'starterwhy',
#   'used',
#   'reliever',
#   'spos',
#   'reardon',
#   'billleewarming',
#   'bullpen',
#   'considering',
#   'monday',
#   'couldnt_touch',
#   'lhplee',
#   'would',
#   'safe_bet',
#   'wasnt',
#   'even',
#   'drug',
#   'thattime',
#   'told',
#   'around',
#   'others',
#   'recent',
#   'venture',
#   'montreal',
#   'blast',
#   'wasnt',
#   'important_aspect',
#   'timingseventh',
#   'game',
#   'tie_game',
#   'top',
#   'expo',
#   'almostcame',
#   'back',
#   'though',
#   'mike_schmidt',
#   'hit',
#   'one',
#   'killed',
#   'expo',
#   'close',
#   'yet',
#   'sofarand',
#   'strawberry',
#   'killed',
#   'pitch',
#   'second',
#   'day',
#   'season',
#   'couple_ofyears',
#   'ago',
#   'went',
#   'technical',
#   'ring',
#   'big',
#   'almost',
#   'leftthe',
#   'stadium',
#   'hit',
#   'hardcorelmark'],
#  [],
#  ['store',
#   'reply_mouse_keyboard',
#   'eventsto',
#   'produce',
#   'regression',
#   'test',
#   'automatic',
#   'demoswe',
#   'would_like',
#   'store',
#   'mouse_keyboard',
#   'eventsproduced',
#   'user',
#   'possible',
#   'filterthe',
#   'mouse_keyboard_event',
#   'server',
#   'queuean',
#   'store',
#   'filethis',
#   'sequence_event',
#   'stored_file',
#   'given',
#   'server_queue',
#   'user',
#   'working',
#   'exists',
#   'tool',
#   'capable',
#   'save',
#   'reply_mouse_keyboard',
#   'event',
#   'one',
#   'catch_event',
#   'store',
#   'case',
#   'server_queue',
#   'terminal',
#   'catch_event',
#   'coming',
#   'given',
#   'server',
#   'possible',
#   'catch_event',
#   'given',
#   'certain',
#   'client',
#   'one',
#   'send',
#   'stored',
#   'sequence_event',
#   'simulate',
#   'user',
#   'central',
#   'dispatcher',
#   'client_machine',
#   'manages',
#   'incoming',
#   'event',
#   'given',
#   'server',
#   'reach',
#   'thanks_advance'],
#  ['whats_story',
#   'stuck',
#   'regulargreen',
#   'red_yelloworange',
#   'led',
#   'give',
#   'anybody_scoop',
#   'fairly_low',
#   'priced',
#   'blue_led',
#   'curiosity',
#   'course',
#   'inspiration_come_badensysbisonmbca_badeninqmindbisonmbca',
#   'seek_baden_bari_unknown'],
#  ['since',
#   'altatheism_hope',
#   'dont_mind',
#   'strongly_disagree',
#   'fact',
#   'god',
#   'could_cause',
#   'believe',
#   'anything',
#   'want',
#   'think',
#   'minute',
#   'would',
#   'rather',
#   'someone',
#   'love',
#   'made',
#   'love',
#   'wanted',
#   'love',
#   'responsibility',
#   'love_god',
#   'take',
#   'step_toward',
#   'promise',
#   'look',
#   'yourselfindeed',
#   'knock',
#   'shall',
#   'opened',
#   'dan',
#   'didnt',
#   'worki',
#   'firmly',
#   'believed_god',
#   'year',
#   'eventually',
#   'realised',
#   'wasonly',
#   'deluding',
#   'fearful',
#   'face',
#   'truth',
#   'ultimately',
#   'reasonwhat',
#   'kept',
#   'believing',
#   'fear_hell',
#   'mental_state',
#   'sillily',
#   'attributed',
#   'divine',
#   'force',
#   'devil',
#   'attempt_destroy',
#   'faith',
#   'nothing',
#   'imagination',
#   'easyto',
#   'achieve',
#   'mental_state',
#   'faith',
#   'learned',
#   'fear',
#   'disguise',
#   'doubt_dispute',
#   'givin',
#   'sincere',
#   'effortgod',
#   'demanding',
#   'much',
#   'dan',
#   'believed',
#   'yearsif',
#   'sincere',
#   'effort',
#   'equivalent',
#   'active',
#   'suspension',
#   'disbelief',
#   'case',
#   'rather',
#   'quit',
#   'god',
#   'help',
#   'tokeep',
#   'faith',
#   'cant',
#   'besides',
#   'concerned',
#   'god',
#   'morality',
#   'mental_health',
#   'doesshe',
#   'really_want',
#   'believe',
#   'without',
#   'help',
#   'revelationsguidance',
#   'anything',
#   'feel',
#   'created',
#   'didntshe',
#   'make',
#   'task',
#   'easier',
#   'supposed',
#   'love',
#   'someone',
#   'whorefuses',
#   'communicate',
#   'point',
#   'eternal',
#   'torturefor',
#   'cant',
#   'believei',
#   'love_god',
#   'much',
#   'love',
#   'want',
#   'seduce',
#   'meshell',
#   'know',
#   'simple_logic',
#   'argument_folly',
#   'read_bible_see',
#   'jesus',
#   'made',
#   'fool',
#   'tried',
#   'trick',
#   'logic',
#   'ability',
#   'reason',
#   'spec',
#   'creation',
#   'yet',
#   'think',
#   'ultimate',
#   'rely',
#   'simply',
#   'reason',
#   'never',
#   'know',
#   'argument',
#   'type',
#   'youll',
#   'know',
#   'tryyet',
#   'many_atheist',
#   'sincerely',
#   'tried',
#   'believedfor',
#   'many_year',
#   'eventually',
#   'honest_enough',
#   'admit',
#   'lived',
#   'virtual',
#   'realitywhat',
#   'else',
#   'reason',
#   'use',
#   'dont',
#   'spiritual',
#   'mean',
#   'christian',
#   'often_refer',
#   'conscience',
#   'disagrees',
#   'biblei',
#   'dont_even',
#   'believe',
#   'soul',
#   'fully_dependent',
#   'mybody',
#   'indeed',
#   'body',
#   'go',
#   'flame',
#   'sodoes',
#   'identity',
#   'god',
#   'entertain',
#   'copy',
#   'meif_want',
#   'learn',
#   'must_accept',
#   'dont_knowwhat_mean',
#   'learn',
#   'must_accept',
#   'dont_know',
#   'something',
#   'righto',
#   'learn',
#   'must_accept',
#   'something_dontknow',
#   'way',
#   'prefer_learn',
#   'unwise',
#   'tomerely',
#   'swallow_everything',
#   'read',
#   'suppose',
#   'write',
#   'book',
#   'tellinghow',
#   'great',
#   'invisible_pink_unicorn',
#   'helped',
#   'mydaily',
#   'problem',
#   'would',
#   'accept',
#   'since',
#   'cant',
#   'know',
#   'whetherit',
#   'true',
#   'notnote',
#   'gipu',
#   'also',
#   'omnipotent',
#   'omnipresent',
#   'love',
#   'justabout',
#   'everyone_besides',
#   'guiding',
#   'every',
#   'writer',
#   'planetyou',
#   'people',
#   'write',
#   'legendary_story',
#   'year',
#   'agoyour',
#   'god',
#   'one',
#   'aspect',
#   'presencepetri'],
#  ['well',
#   'fair_amount',
#   'evidence',
#   'floating_around',
#   'indicatesthat',
#   'oto',
#   'around',
#   'since',
#   'least',
#   'late',
#   'long',
#   'beforecrowley',
#   'ever_heard',
#   'long',
#   'amorc',
#   'around',
#   'yes',
#   'knowthat',
#   'claim',
#   'existed',
#   'organization',
#   'clear',
#   'prehistorybut',
#   'doubt',
#   'organizational',
#   'paperworkas',
#   'nonprofit',
#   'carbondated',
#   'alizard'],
#  ['note',
#   'get',
#   'external',
#   'centris',
#   'willmiss',
#   'sound',
#   'mixing',
#   'feature',
#   'unless',
#   'willing_run',
#   'wirefrom',
#   'motherboard',
#   'sound_input',
#   'connector',
#   'stereo_output',
#   'connecting',
#   'sound_input',
#   'port',
#   'back',
#   'computer',
#   'wont',
#   'dounless',
#   'live',
#   'mono'],
#  ['searching',
#   'one',
#   'two_instructor',
#   'tutorial',
#   'advancedwindows',
#   'programming',
#   'anyone_attended',
#   'course',
#   'wasvery',
#   'good',
#   'would_really_appreciate',
#   'recommendationsplease',
#   'email_directly',
#   'pallerfedunixorg',
#   'dont',
#   'get',
#   'see',
#   'thesenewsgroups',
#   'often',
#   'enoughthanks',
#   'advance_help'],
#  ['latest',
#   'upi',
#   'foreign_ministry_spokesman',
#   'ferhat',
#   'ataman',
#   'told',
#   'journalist',
#   'turkey',
#   'closing',
#   'air_space',
#   'flight',
#   'armenia',
#   'would',
#   'prevent',
#   'humanitarian_aid',
#   'reaching',
#   'republic',
#   'overland',
#   'across',
#   'turkish_territory',
#   'historically',
#   'even',
#   'uncivilized',
#   'people',
#   'exhibited_sign',
#   'compassion',
#   'allowing',
#   'humanitarian_aid',
#   'reach',
#   'civilian_population',
#   'even',
#   'nazi',
#   'much',
#   'seems',
#   'though',
#   'turkey',
#   'publicly',
#   'pronounce',
#   'hypocrite',
#   'choose',
#   'continue',
#   'condemnation',
#   'serbian'],
#  ['maybe_help',
#   'he',
#   'major_league',
#   'coach',
#   'rockiesso',
#   'prediction',
#   'doubly',
#   'wrongmy',
#   'prediction',
#   'red',
#   'soxcubs',
#   'series',
#   'vikingsbroncos',
#   'superbore',
#   'willoccur',
#   'end',
#   'worldand',
#   'one',
#   'rockie',
#   'finish',
#   'top',
#   'offensive',
#   'catagory',
#   'yearand',
#   'rockie',
#   'starter',
#   'era',
#   'ranger',
#   'fade',
#   'begin',
#   'untilaugust',
#   'theyll',
#   'give',
#   'wayto',
#   'angel',
#   'still',
#   'challenge',
#   'endreally',
#   'making',
#   'may',
#   'god',
#   'strike',
#   'zzzzzzt'],
#  ['yes',
#   'absolutely',
#   'though',
#   'make',
#   'observation_general',
#   'sense',
#   'ofall',
#   'observation_made',
#   'human_being',
#   'therefore',
#   'made',
#   'variousbiases',
#   'message',
#   'leaf',
#   'talk',
#   'hypothesis',
#   'get_back',
#   'equating',
#   'business',
#   'science',
#   'end_result',
#   'gizmo',
#   'producedmy',
#   'point',
#   'isnt',
#   'much',
#   'whether',
#   'novel',
#   'paradigm',
#   'come',
#   'developing',
#   'itperhaps',
#   'youd',
#   'admit',
#   'oversimplification',
#   'part',
#   'topicof',
#   'philosophy',
#   'science',
#   'made',
#   'making',
#   'ithink',
#   'also',
#   'summarizes',
#   'popular',
#   'misconception',
#   'science',
#   'business',
#   'science',
#   'biomedical_research',
#   'doesnt_make',
#   'basic',
#   'assumption',
#   'arent',
#   'discipline',
#   'scientificresearch',
#   'make',
#   'empirical_observation',
#   'form',
#   'hypothesisand',
#   'test',
#   'modern_medicine',
#   'much',
#   'biochemistry',
#   'old',
#   'newtonian',
#   'model',
#   'world',
#   'doubt',
#   'many',
#   'psychologistswould',
#   'appreciate',
#   'put',
#   'outside',
#   'empirical',
#   'world',
#   'view',
#   'psychologyalso',
#   'biochemistry',
#   'spoon',
#   'bending',
#   'oversimplified',
#   'course',
#   'good_example',
#   'empirical_observation',
#   'tested',
#   'though',
#   'perhaps',
#   'aristotle',
#   'eventually',
#   'found',
#   'wanting',
#   'meantime',
#   'folk',
#   'continued',
#   'believe',
#   'spontaneous_generation',
#   'animal_life',
#   'there_nothing',
#   'surprising',
#   'way',
#   'gathering',
#   'ofknowledge',
#   'work',
#   'probably',
#   'thing',
#   'discipline',
#   'molecular_biology',
#   'found_totally',
#   'offbaseeven',
#   'idiotic',
#   'someone',
#   'future_future',
#   'people',
#   'wont',
#   'cometo',
#   'relevations',
#   'suddenly',
#   'gone',
#   'zenlike',
#   'vision',
#   'lsd',
#   'trip',
#   'someone',
#   'thought',
#   'something',
#   'new',
#   'tested',
#   'bit',
#   'people',
#   'seem',
#   'relish',
#   'misrepresentingscience',
#   'research',
#   'cant_seem',
#   'wrap',
#   'mind',
#   'around',
#   'science',
#   'creative_process',
#   'think',
#   'factual',
#   'good',
#   'research',
#   'totallyturned',
#   'head',
#   'tommorrow',
#   'new',
#   'result',
#   'theory'],
#  ['following',
#   'ibm_hardware',
#   'forsaleati_vgawonderxl',
#   'great',
#   'card',
#   'support_color_color',
#   'million_color_found',
#   'also',
#   'speed',
#   'window_considerably',
#   'asking_obo_cardi',
#   'also',
#   'baud_modem_doc',
#   'dont_original_box',
#   'work_fine',
#   'like',
#   'get'],
#  ['checked',
#   'setting',
#   'drive_floppy',
#   'setting',
#   'drive',
#   'foppy',
#   'cable',
#   'connecting',
#   'two',
#   'drive',
#   'tothe',
#   'controller_card',
#   'cant_remember',
#   'whichtwo',
#   'wire',
#   'swapped',
#   'determinewhich',
#   'drive',
#   'hope_help_steve'],
#  ['humanist', 'subhumanist'],
#  ['ive',
#   'prki',
#   'would_suggest',
#   'asking',
#   'doctor',
#   'contact',
#   'mine',
#   'said',
#   'yes',
#   'tocontacts',
#   'think',
#   'scar',
#   'would_preclude',
#   'contactsno',
#   'make',
#   'radial',
#   'cut',
#   'around',
#   'circumference',
#   'cornea',
#   'think',
#   'change',
#   'curvature_cornea',
#   'stresschages',
#   'prk_vaporizes',
#   'burn_away',
#   'thin_layer',
#   'front',
#   'thecornea',
#   'making',
#   'optical_axis',
#   'eye',
#   'shorter',
#   'laser',
#   'doesntcut',
#   'prk_vaporizes',
#   'eye',
#   'cut',
#   'intoi',
#   'find',
#   'vision',
#   'clear',
#   'thing',
#   'le_clear',
#   'forothers',
#   'night',
#   'notice',
#   'definite',
#   'haloing',
#   'night',
#   'thedarkness',
#   'look',
#   'automobile',
#   'headlamp',
#   'though',
#   'notsomething',
#   'spend',
#   'inordinate',
#   'amount_time',
#   'ordinarythings',
#   'vision',
#   'particular',
#   'fullyoperating',
#   'peripheralvision',
#   'clearer',
#   'glass_contact'],
#  ['actually', 'several', 'sharware', 'utility', 'change', 'fav', 'isplugin'],
#  ['excerpt',
#   'netnewsscielectronics',
#   'apr',
#   'nuclearsites',
#   'rtimcosletcupportal',
#   'great',
#   'explaination',
#   'however',
#   'left',
#   'one',
#   'detail',
#   'alwayssee',
#   'nuclear_plant',
#   'always',
#   'fossil_fuel_plant',
#   'atnuclear',
#   'plant',
#   'prefered',
#   'run',
#   'water',
#   'closed',
#   'cycle',
#   'whereasfossil',
#   'fuel_plant',
#   'case',
#   'get_away',
#   'dumping',
#   'hotwater',
#   'recall',
#   'water',
#   'isnt',
#   'hot',
#   'thermodynamically',
#   'manyfossil',
#   'fuel_plant',
#   'course',
#   'le',
#   'danger',
#   'radioactivecontamination'],
#  ...]

# %%
dict_LDA = corpora.Dictionary(tokens)
dict_LDA.filter_extremes(no_below=3)
corpus = [dict_LDA.doc2bow(token) for token in tokens]

# %%
from gensim import models

lda = models.LdaModel(corpus, num_topics=20,
                      id2word=dict_LDA,
                      passes=4, alpha=[0.01] * 20,
                      eta=[0.01] * len(dict_LDA.keys()))

# %%
print(lda.print_topics(num_topics=20, num_words=20))
# Out:
# [(0, '0.055*"god" + 0.017*"jesus" + 0.016*"church" + 0.015*"one" + 0.011*"sin" + 0.011*"man" + 0.011*"lord" + 0.010*"christian" + 0.010*"say" + 0.010*"christ" + 0.009*"father" + 0.008*"life" + 0.008*"come" + 0.008*"said" + 0.008*"came" + 0.008*"also" + 0.007*"prayer" + 0.006*"would" + 0.006*"love" + 0.006*"bible"'), (1, '0.014*"get" + 0.012*"driver" + 0.009*"problem" + 0.009*"got" + 0.009*"like" + 0.008*"one" + 0.008*"really" + 0.007*"psalm" + 0.007*"think" + 0.007*"something" + 0.007*"home" + 0.007*"say" + 0.006*"know" + 0.006*"come" + 0.006*"going" + 0.005*"mouse" + 0.005*"well" + 0.005*"dont" + 0.005*"told" + 0.005*"little"'), (2, '0.022*"information" + 0.017*"list" + 0.013*"email" + 0.012*"book" + 0.011*"available" + 0.009*"mail" + 0.009*"address" + 0.009*"sale" + 0.009*"new" + 0.008*"send" + 0.008*"may" + 0.008*"group" + 0.007*"interested" + 0.007*"service" + 0.007*"offer" + 0.007*"conference" + 0.007*"name" + 0.007*"copy" + 0.007*"paper" + 0.006*"computer"'), (3, '0.014*"well" + 0.013*"bike" + 0.010*"like" + 0.010*"back" + 0.010*"one" + 0.009*"dont" + 0.008*"time" + 0.008*"look" + 0.008*"got" + 0.008*"put" + 0.007*"get" + 0.007*"little" + 0.007*"still" + 0.007*"know" + 0.007*"way" + 0.006*"take" + 0.006*"turn" + 0.006*"road" + 0.006*"right" + 0.006*"looking"'), (4, '0.018*"car" + 0.012*"get" + 0.009*"one" + 0.009*"would" + 0.009*"first" + 0.007*"back" + 0.006*"also" + 0.005*"time" + 0.005*"could" + 0.004*"moon" + 0.004*"try" + 0.004*"like" + 0.004*"used" + 0.004*"line" + 0.004*"give" + 0.003*"since" + 0.003*"lead" + 0.003*"new" + 0.003*"second" + 0.003*"motorcycle"'), (5, '0.012*"also" + 0.010*"patient" + 0.009*"one" + 0.008*"kinsey" + 0.007*"doctor" + 0.007*"may" + 0.006*"disease" + 0.006*"case" + 0.006*"treatment" + 0.006*"work" + 0.006*"get" + 0.006*"cause" + 0.006*"universe" + 0.005*"found" + 0.005*"since" + 0.005*"usually" + 0.004*"time" + 0.004*"article" + 0.004*"use" + 0.004*"aid"'), (6, '0.010*"gateway" + 0.009*"surveillance" + 0.008*"sperm" + 0.007*"van" + 0.007*"tor" + 0.007*"voyager" + 0.007*"king" + 0.007*"desktop" + 0.006*"defeated" + 0.006*"ear" + 0.006*"shareware" + 0.006*"icon" + 0.005*"iraqi" + 0.005*"wicked" + 0.005*"philadelphia" + 0.005*"hunter" + 0.005*"pit" + 0.005*"san_jose" + 0.004*"current_version" + 0.004*"tissue"'), (7, '0.016*"people" + 0.016*"one" + 0.015*"would" + 0.010*"think" + 0.009*"say" + 0.007*"know" + 0.006*"way" + 0.006*"may" + 0.006*"thing" + 0.006*"see" + 0.006*"even" + 0.005*"believe" + 0.005*"make" + 0.005*"mean" + 0.005*"point" + 0.005*"right" + 0.005*"dont" + 0.005*"fact" + 0.005*"like" + 0.004*"many"'), (8, '0.020*"use" + 0.014*"file" + 0.014*"program" + 0.014*"window" + 0.012*"system" + 0.011*"using" + 0.010*"one" + 0.010*"also" + 0.009*"get" + 0.008*"problem" + 0.008*"application" + 0.008*"need" + 0.007*"work" + 0.007*"run" + 0.007*"set" + 0.006*"image" + 0.006*"user" + 0.006*"may" + 0.006*"data" + 0.006*"version"'), (9, '0.010*"said" + 0.008*"people" + 0.008*"president" + 0.008*"going" + 0.008*"government" + 0.008*"gun" + 0.006*"state" + 0.006*"job" + 0.006*"well" + 0.005*"say" + 0.005*"law" + 0.005*"time" + 0.005*"firearm" + 0.005*"also" + 0.004*"right" + 0.004*"would" + 0.004*"work" + 0.004*"one" + 0.004*"new" + 0.004*"fbi"'), (10, '0.008*"compuserve" + 0.007*"baud" + 0.007*"iron" + 0.006*"file" + 0.006*"image" + 0.005*"todo" + 0.005*"jpeg" + 0.005*"dept" + 0.005*"file_format" + 0.004*"displayed" + 0.004*"help_appreciated" + 0.004*"may" + 0.004*"thereare" + 0.004*"didnt_find" + 0.004*"linked" + 0.004*"program" + 0.004*"format" + 0.004*"smell" + 0.003*"rid" + 0.003*"rsa_data_security_inc"'), (11, '0.019*"card" + 0.019*"drive" + 0.013*"mac" + 0.013*"system" + 0.013*"one" + 0.010*"board" + 0.010*"used" + 0.009*"need" + 0.008*"also" + 0.008*"work" + 0.008*"disk" + 0.008*"chip" + 0.008*"apple" + 0.008*"problem" + 0.007*"new" + 0.007*"monitor" + 0.007*"use" + 0.006*"machine" + 0.006*"cpu" + 0.006*"computer"'), (12, '0.012*"book" + 0.009*"word" + 0.007*"one" + 0.007*"paul" + 0.0 ...

# %%
# represent each document as a vector of topic weights and fill Nan with 0
doc_lda = lda[corpus]
doc_lda = [[topic[1] for topic in doc] for doc in doc_lda]
doc_lda = pd.DataFrame(doc_lda)
doc_lda.columns = ['topic_'+str(i) for i in range(20)]
doc_lda = doc_lda.fillna(0)
doc_lda = doc_lda[0:100]
dummy_data = doc_lda.to_csv('dummy_data.csv', index=False)
